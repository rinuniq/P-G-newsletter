# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# define file path and sheet names
file_path = "MAIN_Penetration and Value Drivers Template_raw data for Divyaa & Rinu v2.xlsx"
sheet1 = "Penetration Trends Template"
sheet2 = "KPIs - EU5 template"

# load both sheets skipping raw1 and assigning multi-row headers
# df1: skip first row then next 4 rows as headers
# df2: skip first row then next 2 rows as headers

df1 = pd.read_excel(
    file_path,
    sheet_name=sheet1,
   skiprows=1,
    header=[0,1,2,3]
)

df2 = pd.read_excel(
    file_path,
    sheet_name=sheet2,
    skiprows=1,
    header=[0,1]
)

# show some info
print("df1 shape:", df1.shape)
print("df1 columns:\n", df1.columns)
print("df2 shape:", df2.shape)
print("df2 columns:\n", df2.columns)
# Out:
# C:\Users\rdi5001\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)
# df1 shape: (3074, 31)
# df1 columns:
#  MultiIndex([(            'Unnamed: 0_level_0', 'Unnamed: 0_level_1', ...),
#             (            'Unnamed: 1_level_0', 'Unnamed: 1_level_1', ...),
#             (            'Unnamed: 2_level_0', 'Unnamed: 2_level_1', ...),
#             (            'Unnamed: 3_level_0', 'Unnamed: 3_level_1', ...),
#             (            'Unnamed: 4_level_0', 'Unnamed: 4_level_1', ...),
#             (            'Unnamed: 5_level_0', 'Unnamed: 5_level_1', ...),
#             (            'Unnamed: 6_level_0', 'Unnamed: 6_level_1', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...)],
#            )
# df2 shape: (5265, 18)
# df2 columns:
#  MultiIndex([(        'Unnamed: 0_level_0', ...),
#             (        'Unnamed: 1_level_0', ...),
#             (        'Unnamed: 2_level_0', ...),
#             (        'Unnamed: 3_level_0', ...),
#             (        'Unnamed: 4_level_0', ...),
#             (        'Unnamed: 5_level_0', ...),
#             (        'Unnamed: 6_level_0', ...),
#             (        'Unnamed: 7_level_0', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...)],
#            )
# C:\Users\rdi5001\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)

# %%
df1
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0    Unnamed: 5_level_0  \
#      Unnamed: 3_level_1 Unnamed: 4_level_1    Unnamed: 5_level_1
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_0                Penetration  \
#                    Unnamed: 6_level_1               Total Europe
#                    Unnamed: 6_level_2         Unnamed: 7_level_2
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                             \
#
#              Unnamed: 8_level_2                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                 Penetration vs YA (Abs Change)  \
#                                                   Total Europe
#                                            Unnamed: 19_level_2
#      Latest 26 Wks - w/e W4 Y26     Latest 52 Wks - w/e W4 Y26
# 0                         7.331                         -0.216
# 1                         5.643                          1.210
# 2                         0.860                          0.016
# 3                           NaN                         -0.102
# 4                           NaN                         -0.001
# ...                         ...                            ...
# 3069                      0.002                         -0.048
# 3070                        NaN                         -0.025
# 3071                      0.002                          0.000
# 3072                        NaN                         -0.014
# 3073                        NaN                          0.087
#
#                                                             \
#
#             Unnamed: 20_level_2                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
df1

# %%
# Replace Unnamed columns in the 3rd header level (level index 2) after column 7 with 'Total Europe'
if isinstance(df1.columns, pd.MultiIndex):
    cols = list(df1.columns)
    new_cols = []
    for i, col in enumerate(cols):
        col_list = list(col)
        if i >= 7 and len(col_list) > 2 and isinstance(col_list[2], str) and col_list[2].startswith('Unnamed'):
            col_list[2] = col_list[1]
        new_cols.append(tuple(col_list))
    df1.columns = pd.MultiIndex.from_tuples(new_cols)

# display updated dataframe
df1
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0    Unnamed: 5_level_0  \
#      Unnamed: 3_level_1 Unnamed: 4_level_1    Unnamed: 5_level_1
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_0                Penetration  \
#                    Unnamed: 6_level_1               Total Europe
#                    Unnamed: 6_level_2               Total Europe
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                             \
#
#                                                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                 Penetration vs YA (Abs Change)  \
#                                                   Total Europe
#                                                   Total Europe
#      Latest 26 Wks - w/e W4 Y26     Latest 52 Wks - w/e W4 Y26
# 0                         7.331                         -0.216
# 1                         5.643                          1.210
# 2                         0.860                          0.016
# 3                           NaN                         -0.102
# 4                           NaN                         -0.001
# ...                         ...                            ...
# 3069                      0.002                         -0.048
# 3070                        NaN                         -0.025
# 3071                      0.002                          0.000
# 3072                        NaN                         -0.014
# 3073                        NaN                          0.087
#
#                                                             \
#
#                                                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
# create a new view of df1 with the first two header rows removed
if isinstance(df1.columns, pd.MultiIndex) and df1.columns.nlevels > 2:
    df1_trimmed = df1.copy()
    df1_trimmed.columns = df1_trimmed.columns.droplevel([0,1])
else:
    df1_trimmed = df1

# display trimmed dataframe
print("Trimmed df1 columns:", df1_trimmed.columns[:10])
df1_trimmed
# Out:
# Trimmed df1 columns: MultiIndex([('Unnamed: 0_level_2',                     'People'),
#             ('Unnamed: 1_level_2',                   'Currency'),
#             ('Unnamed: 2_level_2',                'Total Panel'),
#             ('Unnamed: 3_level_2',              'Total Outlets'),
#             ('Unnamed: 4_level_2',                   'CATEGORY'),
#             ('Unnamed: 5_level_2',                'BRAND OWNER'),
#             ('Unnamed: 6_level_2',                      'BRAND'),
#             (      'Total Europe', 'Latest 52 Wks - w/e W4 Y26'),
#             (      'Total Europe', 'Latest 26 Wks - w/e W4 Y26'),
#             (            'France', 'Latest 52 Wks - w/e W4 Y26')],
#            )
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2  \
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2  \
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_2               Total Europe  \
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                     France  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                         GB  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                    Germany  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                      Italy  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                      Spain  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                               Total Europe  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         7.331                     -0.216
# 1                         5.643                      1.210
# 2                         0.860                      0.016
# 3                           NaN                     -0.102
# 4                           NaN                     -0.001
# ...                         ...                        ...
# 3069                      0.002                     -0.048
# 3070                        NaN                     -0.025
# 3071                      0.002                      0.000
# 3072                        NaN                     -0.014
# 3073                        NaN                      0.087
#
#                                                     France  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                         GB  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                    Germany  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                      Italy  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                      Spain  \
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
df1_trimmed.columns[0:7]
# Out:
# MultiIndex([('Unnamed: 0_level_2',        'People'),
#             ('Unnamed: 1_level_2',      'Currency'),
#             ('Unnamed: 2_level_2',   'Total Panel'),
#             ('Unnamed: 3_level_2', 'Total Outlets'),
#             ('Unnamed: 4_level_2',      'CATEGORY'),
#             ('Unnamed: 5_level_2',   'BRAND OWNER'),
#             ('Unnamed: 6_level_2',         'BRAND')],
#            )

# %%
# alternative transformation using melt, treating first 7 columns as metadata
# use df_base from earlier steps
try:
    df_base = df1_trimmed
except NameError:
    df_base = df1

# determine metadata and data columns by position
metadata_cols = list(df_base.columns[:7])
# we'll slice by position for data rather than by labels

data_cols_raw = list(df_base.columns[7:])

print("Metadata cols:", metadata_cols)
print("First few raw data cols:", data_cols_raw[:5])


# slice the “data” portion of df_base once the first seven metadata
# columns have been removed
data_cols_raw = list(df_base.columns[7:])


# modify header2 (metric) names for data columns starting from original position 26 onwards
# original col index = 7 + idx in data_cols_raw
renamed_data = []
for idx, col in enumerate(data_cols_raw):
    c0, c1 = col
    if (7 + idx) >= 25:  # zero-based original
        c1 = f"{c1} vs YA"
    renamed_data.append((c0, c1))

# slice the data portion of df_base and then rename its columns

df_data = df_base.iloc[:, 7:].copy()
df_data.columns = pd.MultiIndex.from_tuples(renamed_data)

# also extract df_meta for later use

df_meta = df_base.iloc[:, :7].copy()

# flatten df_data columns
flat_cols = [f"{c0}|||{c1}" for c0, c1 in renamed_data]
df_flat = df_data.copy()
df_flat.columns = flat_cols

# add meta columns to flat
for col in metadata_cols:
    colname = col[1]
    df_flat[f"meta|||{colname}"] = df_meta[col].squeeze().values

# preserve row identifier
df_flat = df_flat.reset_index(drop=True)
df_flat['row_id'] = df_flat.index

# melt on metric columns
id_vars = ['row_id'] + [f"meta|||{col[1]}" for col in metadata_cols]
df_melt = df_flat.melt(id_vars=id_vars, var_name='combined', value_name='value')

# split combined
split_cols = df_melt['combined'].str.split('\\|\\|\\|', expand=True)
df_melt['country'] = split_cols[0]
df_melt['metric'] = split_cols[1]

# pivot back
df_final = df_melt.pivot_table(
    index=id_vars + ['country'],
    columns='metric',
    values='value',
    aggfunc='first'
).reset_index()

# clean metadata column names
for col in metadata_cols:
    df_final = df_final.rename(columns={f"meta|||{col[1]}": col[1]})

print("Transformed final shape:", df_final.shape)
print(df_final.head())
# Out:
# Metadata cols: [('Unnamed: 0_level_2', 'People'), ('Unnamed: 1_level_2', 'Currency'), ('Unnamed: 2_level_2', 'Total Panel'), ('Unnamed: 3_level_2', 'Total Outlets'), ('Unnamed: 4_level_2', 'CATEGORY'), ('Unnamed: 5_level_2', 'BRAND OWNER'), ('Unnamed: 6_level_2', 'BRAND')]
# First few raw data cols: [('Total Europe', 'Latest 52 Wks - w/e W4 Y26'), ('Total Europe', 'Latest 26 Wks - w/e W4 Y26'), ('France', 'Latest 52 Wks - w/e W4 Y26'), ('France', 'Latest 26 Wks - w/e W4 Y26'), ('GB', 'Latest 52 Wks - w/e W4 Y26')]
# vs YA should start at data_cols_raw index 12
# Transformed final shape: (8339, 13)
# metric  row_id        People Currency  Total Panel  Total Outlets  \
# 0            0  People Group      EUR  Total Panel  Total Outlets
# 1            0  People Group      EUR  Total Panel  Total Outlets
# 2            0  People Group      EUR  Total Panel  Total Outlets
# 3            0  People Group      EUR  Total Panel  Total Outlets
# 4            0  People Group      EUR  Total Panel  Total Outlets
#
# metric          CATEGORY BRAND OWNER         BRAND  country  \
# 0       ABRASIVE CL PADS          3M  SCOTCH BRITE   France
# 1       ABRASIVE CL PADS          3M  SCOTCH BRITE       GB
# 2       ABRASIVE CL PADS          3M  SCOTCH BRITE  Germany
# 3       ABRASIVE CL PADS          3M  SCOTCH BRITE    Italy
# 4       ABRASIVE CL PADS          3M  SCOTCH BRITE    Spain
#
# metric  Latest 26 Wks - w/e W4 Y26  Latest 26 Wks - w/e W4 Y26 vs YA  \
# 0                            1.347                               NaN
# 1                            0.328                               NaN
# 2                            0.025                             0.025
# 3                            4.423                            -0.775
# 4                            7.331                            -0.282
#
# metric  Latest 52 Wks - w/e W4 Y26  Latest 52 Wks - w/e W4 Y26 vs YA
# 0                            2.819                               NaN
# 1                            0.578                               NaN
# 2                            0.025                             0.000
# 3                            6.966                            -1.439
# 4                           12.530                             0.306

# %%
df_final.columns.tolist()[7:24]
# Out:
# ['BRAND',
#  'country',
#  'Latest 26 Wks',
#  'Latest 26 Wks vs YA',
#  'Latest 52 Wks',
#  'Latest 52 Wks vs YA']

# %%
df_final.columns=['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
       'CATEGORY', 'BRAND OWNER', 'BRAND', 'country',
       'Latest 26 Wks', 'Latest 26 vs YA',
       'Latest 52 Wks', 'Latest 52 vs YA']

# %%
df_final = df_final.fillna(0)

print("NaN values after filling:")
print(df_final.isna().sum())
# Out:
# NaN values after filling:
# row_id             0
# People             0
# Currency           0
# Total Panel        0
# Total Outlets      0
# CATEGORY           0
# BRAND OWNER        0
# BRAND              0
# country            0
# Latest 26 Wks      0
# Latest 26 vs YA    0
# Latest 52 Wks      0
# Latest 52 vs YA    0
# dtype: int64

# %% [markdown]
# # >2pp

# %%
df_final['Tangible Brands'] = df_final['Latest 52 Wks'].apply(lambda x: 'Yes' if x > 2 else 'No')

# display a sample
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347            0.000          2.819
# 1               GB          0.328            0.000          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.000          0.256
# 8336        France          0.005            0.000          0.005
# 8337            GB          0.302            0.000          0.450
# 8338  Total Europe          0.059            0.000          0.087
#
#       Latest 52 vs YA Tangible Brands
# 0               0.000             Yes
# 1               0.000              No
# 2               0.000              No
# 3              -1.439             Yes
# 4               0.306             Yes
# ...               ...             ...
# 8334            0.000              No
# 8335            0.000              No
# 8336            0.000              No
# 8337            0.000              No
# 8338            0.000              No
#
# [8339 rows x 14 columns]

# %%
df_final.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA'],
#       dtype='object')

# %% [markdown]
# # Growing penetration, Latest 26w vs year ago should be greater than .2

# %%
df_final['Growing Penetration'] = df_final['Latest 26 vs YA'].apply(lambda x: 'Yes' if x > 0.2 else 'No')

df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347            0.000          2.819
# 1               GB          0.328            0.000          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.000          0.256
# 8336        France          0.005            0.000          0.005
# 8337            GB          0.302            0.000          0.450
# 8338  Total Europe          0.059            0.000          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration
# 0               0.000             Yes                  No
# 1               0.000              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335            0.000              No                  No
# 8336            0.000              No                  No
# 8337            0.000              No                  No
# 8338            0.000              No                  No
#
# [8339 rows x 15 columns]

# %%
df_final['Growing Penetration'].value_counts()
# Out:
# Growing Penetration
# No     7959
# Yes     380
# Name: count, dtype: int64

# %% [markdown]
# # Accelerating Penetration
# - Penetration growth in latest 26 weeks vs YA  is greater than penetration change in latest 52. Consider only YA.

# %%
df_final['Accelerating Penetration'] = (df_final['Latest 26 vs YA'] > df_final['Latest 52 vs YA']).apply(lambda x: 'Yes' if x else 'No')

df_final[['BRAND', 'country', 'Latest 26 vs YA', 'Latest 52 vs YA', 'Accelerating Penetration']].head(10)
# Out:
#           BRAND       country  Latest 26 vs YA  Latest 52 vs YA  \
# 0  SCOTCH BRITE        France            0.000            0.000
# 1  SCOTCH BRITE            GB            0.000            0.000
# 2  SCOTCH BRITE       Germany            0.025            0.000
# 3  SCOTCH BRITE         Italy           -0.775           -1.439
# 4  SCOTCH BRITE         Spain           -0.282            0.306
# 5  SCOTCH BRITE  Total Europe            0.000            0.000
# 6     ALL OTHER        France            0.000            0.000
# 7     ALL OTHER            GB            0.000            0.000
# 8     ALL OTHER       Germany            1.342            0.877
# 9     ALL OTHER         Italy            0.724            1.566
#
#   Accelerating Penetration
# 0                       No
# 1                       No
# 2                      Yes
# 3                      Yes
# 4                       No
# 5                       No
# 6                       No
# 7                       No
# 8                      Yes
# 9                       No

# %%
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347            0.000          2.819
# 1               GB          0.328            0.000          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.000          0.256
# 8336        France          0.005            0.000          0.005
# 8337            GB          0.302            0.000          0.450
# 8338  Total Europe          0.059            0.000          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration  \
# 0               0.000             Yes                  No
# 1               0.000              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335            0.000              No                  No
# 8336            0.000              No                  No
# 8337            0.000              No                  No
# 8338            0.000              No                  No
#
#      Accelerating Penetration
# 0                          No
# 1                          No
# 2                         Yes
# 3                         Yes
# 4                          No
# ...                       ...
# 8334                       No
# 8335                       No
# 8336                       No
# 8337                       No
# 8338                       No
#
# [8339 rows x 16 columns]

# %%
df_final['Top Opportunity'] = (
    (df_final['Tangible Brands'] == 'Yes') & 
    (df_final['Growing Penetration'] == 'Yes') & 
    (df_final['Accelerating Penetration'] == 'Yes')
).apply(lambda x: 'Yes' if x else 'No')

# display sample with all columns
df_final[['BRAND', 'country', 'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration', 'Top Opportunity']].head(10)
# Out:
#           BRAND       country Tangible Brands Growing Penetration  \
# 0  SCOTCH BRITE        France             Yes                  No
# 1  SCOTCH BRITE            GB              No                  No
# 2  SCOTCH BRITE       Germany              No                  No
# 3  SCOTCH BRITE         Italy             Yes                  No
# 4  SCOTCH BRITE         Spain             Yes                  No
# 5  SCOTCH BRITE  Total Europe             Yes                  No
# 6     ALL OTHER        France             Yes                  No
# 7     ALL OTHER            GB             Yes                  No
# 8     ALL OTHER       Germany             Yes                 Yes
# 9     ALL OTHER         Italy             Yes                 Yes
#
#   Accelerating Penetration Top Opportunity
# 0                       No              No
# 1                       No              No
# 2                      Yes              No
# 3                      Yes              No
# 4                       No              No
# 5                       No              No
# 6                       No              No
# 7                       No              No
# 8                      Yes             Yes
# 9                       No              No

# %%
Top_Oppurtunity=df_final[df_final['Top Opportunity']=='Yes']
Top_Oppurtunity
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 8          1  People Group      EUR  Total Panel  Total Outlets
# 15         3  People Group      EUR  Total Panel  Total Outlets
# 21         5  People Group      EUR  Total Panel  Total Outlets
# 30         7  People Group      EUR  Total Panel  Total Outlets
# 62        18  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 7622    2809  People Group      EUR  Total Panel  Total Outlets
# 7632    2812  People Group      EUR  Total Panel  Total Outlets
# 7695    2832  People Group      EUR  Total Panel  Total Outlets
# 7866    2903  People Group      EUR  Total Panel  Total Outlets
# 8055    2974  People Group      EUR  Total Panel  Total Outlets
#
#                  CATEGORY        BRAND OWNER                      BRAND  \
# 8        ABRASIVE CL PADS          ALL OTHER                  ALL OTHER
# 15       ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)
# 21       ABRASIVE CL PADS        FREUDENBERG                     VILEDA
# 30       ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX
# 62           ADULT INCONT             ESSITY              TENA (ESSITY)
# ...                   ...                ...                        ...
# 7622           TOOTHPASTE      PRIVATE LABEL              PRIVATE LABEL
# 7632           TOOTHPASTE   PROCTER & GAMBLE                     ORAL B
# 7695  VITAMIN SUPPLEMENTS          ALL OTHER                  ALL OTHER
# 7866       SKIN CLEANSING       BOLTON GROUP            ACQUA ALLE ROSE
# 8055       SKIN CLEANSING     KIMBERLY CLARK                    HUGGIES
#
#       country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 8     Germany          5.621            1.342          8.716            0.877
# 15      Italy          2.184            0.290          3.350            0.180
# 21    Germany          4.371            0.630          6.745            0.319
# 30      Italy         11.639            1.371         17.913            0.985
# 62    Germany          6.692            1.132          8.908            1.125
# ...       ...            ...              ...            ...              ...
# 7622    Spain         26.097            0.383         34.669           -0.001
# 7632    Italy          6.017            0.406          9.094            0.281
# 7695  Germany         14.466            2.155         19.098            1.344
# 7866    Italy          1.817            0.391          3.015            0.164
# 8055    Italy          1.356            0.337          2.063            0.259
#
#      Tangible Brands Growing Penetration Accelerating Penetration  \
# 8                Yes                 Yes                      Yes
# 15               Yes                 Yes                      Yes
# 21               Yes                 Yes                      Yes
# 30               Yes                 Yes                      Yes
# 62               Yes                 Yes                      Yes
# ...              ...                 ...                      ...
# 7622             Yes                 Yes                      Yes
# 7632             Yes                 Yes                      Yes
# 7695             Yes                 Yes                      Yes
# 7866             Yes                 Yes                      Yes
# 8055             Yes                 Yes                      Yes
#
#      Top Opportunity
# 8                Yes
# 15               Yes
# 21               Yes
# 30               Yes
# 62               Yes
# ...              ...
# 7622             Yes
# 7632             Yes
# 7695             Yes
# 7866             Yes
# 8055             Yes
#
# [112 rows x 17 columns]

# %% [markdown]
# # df2

# %%
# Process df2: Keep MultiIndex to properly extract header0 and header1
df2_copy = df2.copy()

print("df2 original columns (first 12):", df2_copy.columns[:12].tolist())
print("df2 MultiIndex nlevels:", df2_copy.columns.nlevels)

# Identify metadata columns (first 8 by position)
metadata_cols = list(df2_copy.columns[:8])
data_cols = list(df2_copy.columns[8:])

print("\nMetadata columns:", metadata_cols)
print("Data columns count:", len(data_cols))
print("Data columns sample (tuples):", data_cols[:5])

# Process the data columns: extract header0 (time period) + header1 (metric)
renamed_cols = []

for col in data_cols:
    h0, h1 = col[0], col[1]  # col is a tuple (header0, header1)
    
    # Split header0 at '-' and take the first part
    time_period = h0.split('-')[0].strip()
    
    # Combine metric + time period
    new_col = f"{h1} {time_period}"
    renamed_cols.append(new_col)

print("\nRenamed data columns (first 10):", renamed_cols[:10])

# Create new dataframe with renamed columns
df2_meta = df2_copy.iloc[:, :8].copy()
df2_data = df2_copy.iloc[:, 8:].copy()

# Flatten column names to single level
df2_meta.columns = [col[1] for col in df2_meta.columns]
df2_data.columns = renamed_cols

# Concatenate metadata and data
df2_processed = pd.concat([df2_meta, df2_data], axis=1)

print("\ndf2_processed shape:", df2_processed.shape)
print("df2_processed columns:", df2_processed.columns.tolist())
print("\nSample of df2_processed:")
df2_processed
# Out:
# df2 original columns (first 12): [('Unnamed: 0_level_0', 'People'), ('Unnamed: 1_level_0', 'Currency'), ('Unnamed: 2_level_0', 'Total Panel'), ('Unnamed: 3_level_0', 'Total Outlets'), ('Unnamed: 4_level_0', 'Countries'), ('Unnamed: 5_level_0', 'CATEGORY'), ('Unnamed: 6_level_0', 'BRAND OWNER'), ('Unnamed: 7_level_0', 'BRAND'), ('Latest 52 Wks - w/e W4 Y26', 'Penetration'), ('Latest 52 Wks - w/e W4 Y26', 'Value vs YA (Abs Change)'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Buyers YA'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Occasions per Buyer YA')]
# df2 MultiIndex nlevels: 2
#
# Metadata columns: [('Unnamed: 0_level_0', 'People'), ('Unnamed: 1_level_0', 'Currency'), ('Unnamed: 2_level_0', 'Total Panel'), ('Unnamed: 3_level_0', 'Total Outlets'), ('Unnamed: 4_level_0', 'Countries'), ('Unnamed: 5_level_0', 'CATEGORY'), ('Unnamed: 6_level_0', 'BRAND OWNER'), ('Unnamed: 7_level_0', 'BRAND')]
# Data columns count: 10
# Data columns sample (tuples): [('Latest 52 Wks - w/e W4 Y26', 'Penetration'), ('Latest 52 Wks - w/e W4 Y26', 'Value vs YA (Abs Change)'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Buyers YA'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Occasions per Buyer YA'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Value per Occasion YA')]
#
# Renamed data columns (first 10): ['Penetration Latest 52 Wks', 'Value vs YA (Abs Change) Latest 52 Wks', 'Value due to Buyers YA Latest 52 Wks', 'Value due to Occasions per Buyer YA Latest 52 Wks', 'Value due to Value per Occasion YA Latest 52 Wks', 'Penetration Latest 26 Wks', 'Value vs YA (Abs Change) Latest 26 Wks', 'Value due to Buyers YA Latest 26 Wks', 'Value due to Occasions per Buyer YA Latest 26 Wks', 'Value due to Value per Occasion YA Latest 26 Wks']
#
# df2_processed shape: (5265, 18)
# df2_processed columns: ['People', 'Currency', 'Total Panel', 'Total Outlets', 'Countries', 'CATEGORY', 'BRAND OWNER', 'BRAND', 'Penetration Latest 52 Wks', 'Value vs YA (Abs Change) Latest 52 Wks', 'Value due to Buyers YA Latest 52 Wks', 'Value due to Occasions per Buyer YA Latest 52 Wks', 'Value due to Value per Occasion YA Latest 52 Wks', 'Penetration Latest 26 Wks', 'Value vs YA (Abs Change) Latest 26 Wks', 'Value due to Buyers YA Latest 26 Wks', 'Value due to Occasions per Buyer YA Latest 26 Wks', 'Value due to Value per Occasion YA Latest 26 Wks']
#
# Sample of df2_processed:
#             People Currency  Total Panel  Total Outlets Countries  \
# 0     People Group      EUR  Total Panel  Total Outlets    France
# 1     People Group      EUR  Total Panel  Total Outlets    France
# 2     People Group      EUR  Total Panel  Total Outlets    France
# 3     People Group      EUR  Total Panel  Total Outlets    France
# 4     People Group      EUR  Total Panel  Total Outlets    France
# ...            ...      ...          ...            ...       ...
# 5260  People Group      EUR  Total Panel  Total Outlets     Spain
# 5261  People Group      EUR  Total Panel  Total Outlets     Spain
# 5262  People Group      EUR  Total Panel  Total Outlets     Spain
# 5263  People Group      EUR  Total Panel  Total Outlets     Spain
# 5264  People Group      EUR  Total Panel  Total Outlets     Spain
#
#               CATEGORY           BRAND OWNER                         BRAND  \
# 0     ABRASIVE CL PADS                    3M                  SCOTCH BRITE
# 1     ABRASIVE CL PADS             ALL OTHER                     ALL OTHER
# 2     ABRASIVE CL PADS     COLGATE PALMOLIVE      AJAX (COLGATE PALMOLIVE)
# 3     ABRASIVE CL PADS           FREUDENBERG                        VILEDA
# 4     ABRASIVE CL PADS         NEWELL BRANDS                       SPONTEX
# ...                ...                   ...                           ...
# 5260    SKIN CLEANSING               SODALIS             VITESSE (SODALIS)
# 5261    SKIN CLEANSING              UNILEVER    DOVE (UNILEVER / UNILEVER)
# 5262    SKIN CLEANSING              UNILEVER     REN (UNILEVER / UNILEVER)
# 5263    SKIN CLEANSING                WELEDA                        WELEDA
# 5264    SKIN CLEANSING  YELLOW WOOD PARTNERS  PONDS (YELLOW WOOD PARTNERS)
#
#       Penetration Latest 52 Wks  Value vs YA (Abs Change) Latest 52 Wks  \
# 0                         2.819                           -2.816270e+05
# 1                        29.041                            1.402825e+07
# 2                           NaN                           -4.565028e+03
# 3                         0.488                            2.342170e+05
# 4                        37.546                            1.144235e+06
# ...                         ...                                     ...
# 5260                      1.049                           -2.577675e+05
# 5261                        NaN                           -2.836982e+04
# 5262                      0.005                            1.886498e+04
# 5263                      0.034                            1.966220e+04
# 5264                      0.011                           -2.534527e+03
#
#       Value due to Buyers YA Latest 52 Wks  \
# 0                              -125211.791
# 1                              5187110.253
# 2                                      NaN
# 3                               310890.571
# 4                              -231956.527
# ...                                    ...
# 5260                           -654667.168
# 5261                                   NaN
# 5262                                   NaN
# 5263                             19322.068
# 5264                             -3278.416
#
#       Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                             -6940.783
# 1                                           4381444.346
# 2                                                   NaN
# 3                                             -2794.563
# 4                                           -777751.959
# ...                                                 ...
# 5260                                         373307.212
# 5261                                                NaN
# 5262                                                NaN
# 5263                                            161.330
# 5264                                              0.000
#
#       Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                          -149477.240
# 1                                          4459689.949
# 2                                                  NaN
# 3                                           -73880.617
# 4                                          2153942.130
# ...                                                ...
# 5260                                         23593.632
# 5261                                               NaN
# 5262                                               NaN
# 5263                                           181.241
# 5264                                           745.103
#
#       Penetration Latest 26 Wks  Value vs YA (Abs Change) Latest 26 Wks  \
# 0                         1.347                             -467747.807
# 1                        19.432                             5185968.980
# 2                           NaN                               -4565.028
# 3                         0.300                               75419.427
# 4                        26.582                              362865.133
# ...                         ...                                     ...
# 5260                      0.864                              -63081.555
# 5261                        NaN                                     NaN
# 5262                        NaN                                     NaN
# 5263                      0.002                                4269.966
# 5264                      0.002                               -4066.432
#
#       Value due to Buyers YA Latest 26 Wks  \
# 0                              -387638.647
# 1                              1594138.737
# 2                                      NaN
# 3                                91236.705
# 4                              -515417.269
# ...                                    ...
# 5260                             92476.682
# 5261                                   NaN
# 5262                                   NaN
# 5263                                   NaN
# 5264                             -4573.227
#
#       Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                             92471.589
# 1                                           1249741.075
# 2                                                   NaN
# 3                                              -150.418
# 4                                           -508856.667
# ...                                                 ...
# 5260                                        -167001.323
# 5261                                                NaN
# 5262                                                NaN
# 5263                                                NaN
# 5264                                             44.810
#
#       Value due to Value per Occasion YA Latest 26 Wks
# 0                                          -172577.218
# 1                                          2342089.327
# 2                                                  NaN
# 3                                           -15666.805
# 4                                          1387139.758
# ...                                                ...
# 5260                                         11444.334
# 5261                                               NaN
# 5262                                               NaN
# 5263                                               NaN
# 5264                                           466.165
#
# [5265 rows x 18 columns]

# %%
df2_processed=df2_processed.fillna(0)
df2_processed
# Out:
#             People Currency  Total Panel  Total Outlets Countries  \
# 0     People Group      EUR  Total Panel  Total Outlets    France
# 1     People Group      EUR  Total Panel  Total Outlets    France
# 2     People Group      EUR  Total Panel  Total Outlets    France
# 3     People Group      EUR  Total Panel  Total Outlets    France
# 4     People Group      EUR  Total Panel  Total Outlets    France
# ...            ...      ...          ...            ...       ...
# 5260  People Group      EUR  Total Panel  Total Outlets     Spain
# 5261  People Group      EUR  Total Panel  Total Outlets     Spain
# 5262  People Group      EUR  Total Panel  Total Outlets     Spain
# 5263  People Group      EUR  Total Panel  Total Outlets     Spain
# 5264  People Group      EUR  Total Panel  Total Outlets     Spain
#
#               CATEGORY           BRAND OWNER                         BRAND  \
# 0     ABRASIVE CL PADS                    3M                  SCOTCH BRITE
# 1     ABRASIVE CL PADS             ALL OTHER                     ALL OTHER
# 2     ABRASIVE CL PADS     COLGATE PALMOLIVE      AJAX (COLGATE PALMOLIVE)
# 3     ABRASIVE CL PADS           FREUDENBERG                        VILEDA
# 4     ABRASIVE CL PADS         NEWELL BRANDS                       SPONTEX
# ...                ...                   ...                           ...
# 5260    SKIN CLEANSING               SODALIS             VITESSE (SODALIS)
# 5261    SKIN CLEANSING              UNILEVER    DOVE (UNILEVER / UNILEVER)
# 5262    SKIN CLEANSING              UNILEVER     REN (UNILEVER / UNILEVER)
# 5263    SKIN CLEANSING                WELEDA                        WELEDA
# 5264    SKIN CLEANSING  YELLOW WOOD PARTNERS  PONDS (YELLOW WOOD PARTNERS)
#
#       Penetration Latest 52 Wks  Value vs YA (Abs Change) Latest 52 Wks  \
# 0                         2.819                           -2.816270e+05
# 1                        29.041                            1.402825e+07
# 2                         0.000                           -4.565028e+03
# 3                         0.488                            2.342170e+05
# 4                        37.546                            1.144235e+06
# ...                         ...                                     ...
# 5260                      1.049                           -2.577675e+05
# 5261                      0.000                           -2.836982e+04
# 5262                      0.005                            1.886498e+04
# 5263                      0.034                            1.966220e+04
# 5264                      0.011                           -2.534527e+03
#
#       Value due to Buyers YA Latest 52 Wks  \
# 0                              -125211.791
# 1                              5187110.253
# 2                                    0.000
# 3                               310890.571
# 4                              -231956.527
# ...                                    ...
# 5260                           -654667.168
# 5261                                 0.000
# 5262                                 0.000
# 5263                             19322.068
# 5264                             -3278.416
#
#       Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                             -6940.783
# 1                                           4381444.346
# 2                                                 0.000
# 3                                             -2794.563
# 4                                           -777751.959
# ...                                                 ...
# 5260                                         373307.212
# 5261                                              0.000
# 5262                                              0.000
# 5263                                            161.330
# 5264                                              0.000
#
#       Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                          -149477.240
# 1                                          4459689.949
# 2                                                0.000
# 3                                           -73880.617
# 4                                          2153942.130
# ...                                                ...
# 5260                                         23593.632
# 5261                                             0.000
# 5262                                             0.000
# 5263                                           181.241
# 5264                                           745.103
#
#       Penetration Latest 26 Wks  Value vs YA (Abs Change) Latest 26 Wks  \
# 0                         1.347                             -467747.807
# 1                        19.432                             5185968.980
# 2                         0.000                               -4565.028
# 3                         0.300                               75419.427
# 4                        26.582                              362865.133
# ...                         ...                                     ...
# 5260                      0.864                              -63081.555
# 5261                      0.000                                   0.000
# 5262                      0.000                                   0.000
# 5263                      0.002                                4269.966
# 5264                      0.002                               -4066.432
#
#       Value due to Buyers YA Latest 26 Wks  \
# 0                              -387638.647
# 1                              1594138.737
# 2                                    0.000
# 3                                91236.705
# 4                              -515417.269
# ...                                    ...
# 5260                             92476.682
# 5261                                 0.000
# 5262                                 0.000
# 5263                                 0.000
# 5264                             -4573.227
#
#       Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                             92471.589
# 1                                           1249741.075
# 2                                                 0.000
# 3                                              -150.418
# 4                                           -508856.667
# ...                                                 ...
# 5260                                        -167001.323
# 5261                                              0.000
# 5262                                              0.000
# 5263                                              0.000
# 5264                                             44.810
#
#       Value due to Value per Occasion YA Latest 26 Wks
# 0                                          -172577.218
# 1                                          2342089.327
# 2                                                0.000
# 3                                           -15666.805
# 4                                          1387139.758
# ...                                                ...
# 5260                                         11444.334
# 5261                                             0.000
# 5262                                             0.000
# 5263                                             0.000
# 5264                                           466.165
#
# [5265 rows x 18 columns]

# %%
df2_processed.columns
# Out:
# Index(['People', 'Currency', 'Total Panel', 'Total Outlets', 'Countries',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'Penetration Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Penetration Latest 26 Wks', 'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')

# %%
Top_Oppurtunity
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 8          1  People Group      EUR  Total Panel  Total Outlets
# 15         3  People Group      EUR  Total Panel  Total Outlets
# 21         5  People Group      EUR  Total Panel  Total Outlets
# 30         7  People Group      EUR  Total Panel  Total Outlets
# 62        18  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 7622    2809  People Group      EUR  Total Panel  Total Outlets
# 7632    2812  People Group      EUR  Total Panel  Total Outlets
# 7695    2832  People Group      EUR  Total Panel  Total Outlets
# 7866    2903  People Group      EUR  Total Panel  Total Outlets
# 8055    2974  People Group      EUR  Total Panel  Total Outlets
#
#                  CATEGORY        BRAND OWNER                      BRAND  \
# 8        ABRASIVE CL PADS          ALL OTHER                  ALL OTHER
# 15       ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)
# 21       ABRASIVE CL PADS        FREUDENBERG                     VILEDA
# 30       ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX
# 62           ADULT INCONT             ESSITY              TENA (ESSITY)
# ...                   ...                ...                        ...
# 7622           TOOTHPASTE      PRIVATE LABEL              PRIVATE LABEL
# 7632           TOOTHPASTE   PROCTER & GAMBLE                     ORAL B
# 7695  VITAMIN SUPPLEMENTS          ALL OTHER                  ALL OTHER
# 7866       SKIN CLEANSING       BOLTON GROUP            ACQUA ALLE ROSE
# 8055       SKIN CLEANSING     KIMBERLY CLARK                    HUGGIES
#
#       country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 8     Germany          5.621            1.342          8.716            0.877
# 15      Italy          2.184            0.290          3.350            0.180
# 21    Germany          4.371            0.630          6.745            0.319
# 30      Italy         11.639            1.371         17.913            0.985
# 62    Germany          6.692            1.132          8.908            1.125
# ...       ...            ...              ...            ...              ...
# 7622    Spain         26.097            0.383         34.669           -0.001
# 7632    Italy          6.017            0.406          9.094            0.281
# 7695  Germany         14.466            2.155         19.098            1.344
# 7866    Italy          1.817            0.391          3.015            0.164
# 8055    Italy          1.356            0.337          2.063            0.259
#
#      Tangible Brands Growing Penetration Accelerating Penetration  \
# 8                Yes                 Yes                      Yes
# 15               Yes                 Yes                      Yes
# 21               Yes                 Yes                      Yes
# 30               Yes                 Yes                      Yes
# 62               Yes                 Yes                      Yes
# ...              ...                 ...                      ...
# 7622             Yes                 Yes                      Yes
# 7632             Yes                 Yes                      Yes
# 7695             Yes                 Yes                      Yes
# 7866             Yes                 Yes                      Yes
# 8055             Yes                 Yes                      Yes
#
#      Top Opportunity
# 8                Yes
# 15               Yes
# 21               Yes
# 30               Yes
# 62               Yes
# ...              ...
# 7622             Yes
# 7632             Yes
# 7695             Yes
# 7866             Yes
# 8055             Yes
#
# [112 rows x 17 columns]

# %%
# merge procedure between Top_Oppurtunity (from df_final) and df2_processed
# assume df_final and df2_processed exist

# select necessary columns from df2_processed
right_cols = [
    'Countries','CATEGORY','BRAND',
    'Value vs YA (Abs Change) Latest 52 Wks',
    'Value due to Buyers YA Latest 52 Wks',
    'Value due to Occasions per Buyer YA Latest 52 Wks',
    'Value due to Value per Occasion YA Latest 52 Wks',
    'Value vs YA (Abs Change) Latest 26 Wks',
    'Value due to Buyers YA Latest 26 Wks',
    'Value due to Occasions per Buyer YA Latest 26 Wks',
    'Value due to Value per Occasion YA Latest 26 Wks',
]

# build small right table
df2_small = df2_processed[right_cols].copy()

# perform left merge
Top_Oppurtunity = df_final[df_final['Top Opportunity']=='Yes']

df_merged = Top_Oppurtunity.merge(
    df2_small,
    left_on=['country','CATEGORY','BRAND'],
    right_on=['Countries','CATEGORY','BRAND'],
    how='left'
)

# drop auxiliary column
if 'Countries' in df_merged.columns:
    df_merged = df_merged.drop(columns=['Countries'])

# show result
print(df_merged.columns)
df_merged.head()
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')
#    row_id        People Currency  Total Panel  Total Outlets  \
# 0       1  People Group      EUR  Total Panel  Total Outlets
# 1       3  People Group      EUR  Total Panel  Total Outlets
# 2       5  People Group      EUR  Total Panel  Total Outlets
# 3       7  People Group      EUR  Total Panel  Total Outlets
# 4      18  People Group      EUR  Total Panel  Total Outlets
#
#            CATEGORY        BRAND OWNER                      BRAND  country  \
# 0  ABRASIVE CL PADS          ALL OTHER                  ALL OTHER  Germany
# 1  ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)    Italy
# 2  ABRASIVE CL PADS        FREUDENBERG                     VILEDA  Germany
# 3  ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX    Italy
# 4      ADULT INCONT             ESSITY              TENA (ESSITY)  Germany
#
#    Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 0          5.621            1.342          8.716            0.877
# 1          2.184            0.290          3.350            0.180
# 2          4.371            0.630          6.745            0.319
# 3         11.639            1.371         17.913            0.985
# 4          6.692            1.132          8.908            1.125
#
#   Tangible Brands Growing Penetration Accelerating Penetration  \
# 0             Yes                 Yes                      Yes
# 1             Yes                 Yes                      Yes
# 2             Yes                 Yes                      Yes
# 3             Yes                 Yes                      Yes
# 4             Yes                 Yes                      Yes
#
#   Top Opportunity  Value vs YA (Abs Change) Latest 52 Wks  \
# 0             Yes                              791926.913
# 1             Yes                              -42369.452
# 2             Yes                              853160.781
# 3             Yes                             1242617.725
# 4             Yes                             6461534.656
#
#    Value due to Buyers YA Latest 52 Wks  \
# 0                          1.110129e+06
# 1                          1.086605e+05
# 2                          4.443390e+05
# 3                          6.870830e+05
# 4                          1.643899e+07
#
#    Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                         260424.394
# 1                                         -68570.221
# 2                                        -420833.153
# 3                                         413898.999
# 4                                       -7256988.559
#
#    Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                       -578625.594
# 1                                        -82461.060
# 2                                        829654.867
# 3                                        141636.099
# 4                                      -2720452.272
#
#    Value vs YA (Abs Change) Latest 26 Wks  \
# 0                              446782.207
# 1                               78686.554
# 2                              609011.228
# 3                              978145.473
# 4                             4688767.982
#
#    Value due to Buyers YA Latest 26 Wks  \
# 0                          1.470200e+06
# 1                          1.437160e+05
# 2                          7.507220e+05
# 3                          7.783581e+05
# 4                          1.146098e+07
#
#    Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                         168429.175
# 1                                         -18118.708
# 2                                        -410890.572
# 3                                         -47557.527
# 4                                       -4419524.947
#
#    Value due to Value per Occasion YA Latest 26 Wks
# 0                                      -1191849.092
# 1                                        -46911.006
# 2                                        269179.707
# 3                                        247345.390
# 4                                      -2352686.459

# %%
df_merged.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')

# %%
# calculate contribution percentages for each value component and week
weeks = ['52','26']
components = ['Value due to Buyers YA','Value due to Occasions per Buyer YA','Value due to Value per Occasion YA']

for wk in weeks:
    denom_col = f'Value vs YA (Abs Change) Latest {wk} Wks'
    for comp in components:
        num_col = f'{comp} Latest {wk} Wks'
        new_col = f'Contribution {comp} Latest {wk} Wks'
        df_merged[new_col] = df_merged[num_col] / df_merged[denom_col] * 100

# inspect new columns
df_merged.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks',
#        'Contribution Value due to Buyers YA Latest 52 Wks',
#        'Contribution Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Contribution Value due to Value per Occasion YA Latest 52 Wks',
#        'Contribution Value due to Buyers YA Latest 26 Wks',
#        'Contribution Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Contribution Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')

# %%
df_merged
# Out:
#      row_id        People Currency  Total Panel  Total Outlets  \
# 0         1  People Group      EUR  Total Panel  Total Outlets
# 1         3  People Group      EUR  Total Panel  Total Outlets
# 2         5  People Group      EUR  Total Panel  Total Outlets
# 3         7  People Group      EUR  Total Panel  Total Outlets
# 4        18  People Group      EUR  Total Panel  Total Outlets
# ..      ...           ...      ...          ...            ...
# 107    2809  People Group      EUR  Total Panel  Total Outlets
# 108    2812  People Group      EUR  Total Panel  Total Outlets
# 109    2832  People Group      EUR  Total Panel  Total Outlets
# 110    2903  People Group      EUR  Total Panel  Total Outlets
# 111    2974  People Group      EUR  Total Panel  Total Outlets
#
#                 CATEGORY        BRAND OWNER                      BRAND  \
# 0       ABRASIVE CL PADS          ALL OTHER                  ALL OTHER
# 1       ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)
# 2       ABRASIVE CL PADS        FREUDENBERG                     VILEDA
# 3       ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX
# 4           ADULT INCONT             ESSITY              TENA (ESSITY)
# ..                   ...                ...                        ...
# 107           TOOTHPASTE      PRIVATE LABEL              PRIVATE LABEL
# 108           TOOTHPASTE   PROCTER & GAMBLE                     ORAL B
# 109  VITAMIN SUPPLEMENTS          ALL OTHER                  ALL OTHER
# 110       SKIN CLEANSING       BOLTON GROUP            ACQUA ALLE ROSE
# 111       SKIN CLEANSING     KIMBERLY CLARK                    HUGGIES
#
#      country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 0    Germany          5.621            1.342          8.716            0.877
# 1      Italy          2.184            0.290          3.350            0.180
# 2    Germany          4.371            0.630          6.745            0.319
# 3      Italy         11.639            1.371         17.913            0.985
# 4    Germany          6.692            1.132          8.908            1.125
# ..       ...            ...              ...            ...              ...
# 107    Spain         26.097            0.383         34.669           -0.001
# 108    Italy          6.017            0.406          9.094            0.281
# 109  Germany         14.466            2.155         19.098            1.344
# 110    Italy          1.817            0.391          3.015            0.164
# 111    Italy          1.356            0.337          2.063            0.259
#
#     Tangible Brands Growing Penetration Accelerating Penetration  \
# 0               Yes                 Yes                      Yes
# 1               Yes                 Yes                      Yes
# 2               Yes                 Yes                      Yes
# 3               Yes                 Yes                      Yes
# 4               Yes                 Yes                      Yes
# ..              ...                 ...                      ...
# 107             Yes                 Yes                      Yes
# 108             Yes                 Yes                      Yes
# 109             Yes                 Yes                      Yes
# 110             Yes                 Yes                      Yes
# 111             Yes                 Yes                      Yes
#
#     Top Opportunity  Value vs YA (Abs Change) Latest 52 Wks  \
# 0               Yes                              791926.913
# 1               Yes                              -42369.452
# 2               Yes                              853160.781
# 3               Yes                             1242617.725
# 4               Yes                             6461534.656
# ..              ...                                     ...
# 107             Yes                              292440.626
# 108             Yes                             1981101.690
# 109             Yes                             8623708.885
# 110             Yes                              119001.492
# 111             Yes                               -3092.676
#
#      Value due to Buyers YA Latest 52 Wks  \
# 0                            1.110129e+06
# 1                            1.086605e+05
# 2                            4.443390e+05
# 3                            6.870830e+05
# 4                            1.643899e+07
# ..                                    ...
# 107                          2.631219e+05
# 108                          6.255443e+05
# 109                          1.080711e+07
# 110                          3.545233e+05
# 111                          4.627969e+05
#
#      Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                           260424.394
# 1                                           -68570.221
# 2                                          -420833.153
# 3                                           413898.999
# 4                                         -7256988.559
# ..                                                 ...
# 107                                         159853.843
# 108                                        -305772.939
# 109                                        3044559.870
# 110                                         -42314.824
# 111                                         159714.843
#
#      Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                         -578625.594
# 1                                          -82461.060
# 2                                          829654.867
# 3                                          141636.099
# 4                                        -2720452.272
# ..                                                ...
# 107                                       -130532.641
# 108                                       1661329.651
# 109                                      -5227967.820
# 110                                       -193212.866
# 111                                       -625604.424
#
#      Value vs YA (Abs Change) Latest 26 Wks  \
# 0                              4.467822e+05
# 1                              7.868655e+04
# 2                              6.090112e+05
# 3                              9.781455e+05
# 4                              4.688768e+06
# ..                                      ...
# 107                            2.008156e+05
# 108                            2.206531e+06
# 109                            1.123335e+07
# 110                            5.501768e+05
# 111                            1.199248e+05
#
#      Value due to Buyers YA Latest 26 Wks  \
# 0                            1.470200e+06
# 1                            1.437160e+05
# 2                            7.507220e+05
# 3                            7.783581e+05
# 4                            1.146098e+07
# ..                                    ...
# 107                          3.808380e+05
# 108                          7.431629e+05
# 109                          1.237497e+07
# 110                          7.255667e+05
# 111                          4.884227e+05
#
#      Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                           168429.175
# 1                                           -18118.708
# 2                                          -410890.572
# 3                                           -47557.527
# 4                                         -4419524.947
# ..                                                 ...
# 107                                        -132024.757
# 108                                         283741.985
# 109                                        -957854.403
# 110                                          72770.081
# 111                                        -277301.933
#
#      Value due to Value per Occasion YA Latest 26 Wks  \
# 0                                        -1191849.092
# 1                                          -46911.006
# 2                                          269179.707
# 3                                          247345.390
# 4                                        -2352686.459
# ..                                                ...
# 107                                        -47996.443
# 108                                       1179629.130
# 109                                       -183771.025
# 110                                       -248162.122
# 111                                        -91199.930
#
#      Contribution Value due to Buyers YA Latest 52 Wks  \
# 0                                           140.180709
# 1                                          -256.459477
# 2                                            52.081504
# 3                                            55.293192
# 4                                           254.413105
# ..                                                 ...
# 107                                          89.974453
# 108                                          31.575577
# 109                                         125.318534
# 110                                         297.915032
# 111                                      -14964.288112
#
#      Contribution Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                            32.884903
# 1                                           161.838820
# 2                                           -49.326359
# 3                                            33.308635
# 4                                          -112.310603
# ..                                                 ...
# 107                                          54.661982
# 108                                         -15.434490
# 109                                          35.304530
# 110                                         -35.558230
# 111                                       -5164.292768
#
#      Contribution Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                           -73.065530
# 1                                           194.623853
# 2                                            97.244844
# 3                                            11.398204
# 4                                           -42.102262
# ..                                                 ...
# 107                                         -44.635604
# 108                                          83.858878
# 109                                         -60.623195
# 110                                        -162.361717
# 111                                       20228.579521
#
#      Contribution Value due to Buyers YA Latest 26 Wks  \
# 0                                           329.064162
# 1                                           182.643656
# 2                                           123.268986
# 3                                            79.574886
# 4                                           244.434825
# ..                                                 ...
# 107                                         189.645577
# 108                                          33.680142
# 109                                         110.162817
# 110                                         131.878814
# 111                                         407.274097
#
#      Contribution Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                            37.698273
# 1                                           -23.026435
# 2                                           -67.468472
# 3                                            -4.862010
# 4                                           -94.257702
# ..                                                 ...
# 107                                         -65.744258
# 108                                          12.859187
# 109                                          -8.526882
# 110                                          13.226671
# 111                                        -231.229829
#
#      Contribution Value due to Value per Occasion YA Latest 26 Wks
# 0                                          -266.762882
# 1                                           -59.617563
# 2                                            44.199465
# 3                                            25.287178
# 4                                           -50.177071
# ..                                                 ...
# 107                                         -23.900749
# 108                                          53.460792
# 109                                          -1.635942
# 110                                         -45.105883
# 111                                         -76.047592
#
# [112 rows x 31 columns]

# %%
# Sort df_merged by Value vs YA (Abs Change) Latest 13 Wks in descending order
df_priority = df_merged.sort_values(
    by='Value vs YA (Abs Change) Latest 26 Wks',
    ascending=False
).reset_index(drop=True)

df_priority
# Out:
#      row_id        People Currency  Total Panel  Total Outlets  \
# 0      2832  People Group      EUR  Total Panel  Total Outlets
# 1       920  People Group      EUR  Total Panel  Total Outlets
# 2      2699  People Group      EUR  Total Panel  Total Outlets
# 3      1919  People Group      EUR  Total Panel  Total Outlets
# 4      1711  People Group      EUR  Total Panel  Total Outlets
# ..      ...           ...      ...          ...            ...
# 107     789  People Group      EUR  Total Panel  Total Outlets
# 108     924  People Group      EUR  Total Panel  Total Outlets
# 109     261  People Group      EUR  Total Panel  Total Outlets
# 110    2350  People Group      EUR  Total Panel  Total Outlets
# 111    1939  People Group      EUR  Total Panel  Total Outlets
#
#                 CATEGORY        BRAND OWNER           BRAND  country  \
# 0    VITAMIN SUPPLEMENTS          ALL OTHER       ALL OTHER  Germany
# 1            FABRIC SOFT      PRIVATE LABEL   PRIVATE LABEL    Spain
# 2           TOILET PAPER             ESSITY            ZEWA  Germany
# 3            LAUNDRY DET             HENKEL   WEISSER RIESE  Germany
# 4            HH CLEANERS      PRIVATE LABEL   PRIVATE LABEL  Germany
# ..                   ...                ...             ...      ...
# 107         DEPILATORIES          ALL OTHER       ALL OTHER    Italy
# 108          FABRIC SOFT  RECKITT BENCKISER  FLOR (RECKITT)    Spain
# 109          BATH/SHOWER          ALL OTHER       ALL OTHER  Germany
# 110            SKIN CARE         BEIERSDORF           NIVEA  Germany
# 111          LAUNDRY DET      PRIVATE LABEL   PRIVATE LABEL    Italy
#
#      Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 0           14.466            2.155         19.098            1.344
# 1           55.363            0.493         63.894            0.339
# 2           11.586            1.591         16.281            1.298
# 3            6.458            1.157          9.347           -0.295
# 4           50.808            1.994         64.247            0.263
# ..             ...              ...            ...              ...
# 107          3.367            0.345          5.501            0.280
# 108          7.556            0.471         10.968           -0.007
# 109         22.968            1.195         29.967            0.571
# 110         18.148            0.404         25.663           -0.404
# 111         38.563            0.410         50.380           -0.132
#
#     Tangible Brands Growing Penetration Accelerating Penetration  \
# 0               Yes                 Yes                      Yes
# 1               Yes                 Yes                      Yes
# 2               Yes                 Yes                      Yes
# 3               Yes                 Yes                      Yes
# 4               Yes                 Yes                      Yes
# ..              ...                 ...                      ...
# 107             Yes                 Yes                      Yes
# 108             Yes                 Yes                      Yes
# 109             Yes                 Yes                      Yes
# 110             Yes                 Yes                      Yes
# 111             Yes                 Yes                      Yes
#
#     Top Opportunity  Value vs YA (Abs Change) Latest 52 Wks  \
# 0               Yes                            8.623709e+06
# 1               Yes                            1.675381e+07
# 2               Yes                            6.528892e+06
# 3               Yes                            9.321929e+05
# 4               Yes                            7.358688e+06
# ..              ...                                     ...
# 107             Yes                           -1.548413e+06
# 108             Yes                           -1.264538e+06
# 109             Yes                            2.320751e+05
# 110             Yes                           -4.185241e+07
# 111             Yes                           -8.959337e+06
#
#      Value due to Buyers YA Latest 52 Wks  \
# 0                            1.080711e+07
# 1                            2.521797e+06
# 2                            9.307322e+06
# 3                           -2.031968e+06
# 4                            8.157162e+05
# ..                                    ...
# 107                          4.518025e+05
# 108                          1.617431e+05
# 109                          3.347936e+06
# 110                         -3.663586e+06
# 111                         -1.553815e+05
#
#      Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                         3.044560e+06
# 1                                         1.522746e+07
# 2                                        -8.080408e+06
# 3                                        -5.671527e+04
# 4                                         4.329485e+06
# ..                                                 ...
# 107                                      -1.224573e+06
# 108                                      -5.642667e+05
# 109                                      -3.753642e+05
# 110                                      -8.033894e+06
# 111                                      -1.132845e+07
#
#      Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                       -5.227968e+06
# 1                                       -9.954505e+05
# 2                                        5.301964e+06
# 3                                        3.020884e+06
# 4                                        2.213481e+06
# ..                                                ...
# 107                                     -7.756459e+05
# 108                                     -8.620189e+05
# 109                                     -2.740487e+06
# 110                                     -3.015494e+07
# 111                                      2.524501e+06
#
#      Value vs YA (Abs Change) Latest 26 Wks  \
# 0                              1.123335e+07
# 1                              1.028623e+07
# 2                              9.308653e+06
# 3                              8.096343e+06
# 4                              6.751289e+06
# ..                                      ...
# 107                           -5.181834e+05
# 108                           -7.638931e+05
# 109                           -3.035290e+06
# 110                           -4.139213e+06
# 111                           -4.986660e+06
#
#      Value due to Buyers YA Latest 26 Wks  \
# 0                            1.237497e+07
# 1                            1.631086e+06
# 2                            8.524028e+06
# 3                            6.159855e+06
# 4                            3.765824e+06
# ..                                    ...
# 107                          4.134671e+05
# 108                          7.735781e+05
# 109                          5.140223e+06
# 110                          2.562406e+06
# 111                          1.230215e+06
#
#      Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                        -9.578544e+05
# 1                                         1.135142e+07
# 2                                        -2.425330e+06
# 3                                         2.369565e+05
# 4                                         1.125157e+06
# ..                                                 ...
# 107                                      -3.254312e+05
# 108                                      -9.476240e+05
# 109                                       9.217945e+04
# 110                                      -2.545820e+06
# 111                                      -7.298662e+06
#
#      Value due to Value per Occasion YA Latest 26 Wks  \
# 0                                         -183771.025
# 1                                        -2696273.492
# 2                                         3209951.565
# 3                                         1699532.092
# 4                                         1860310.712
# ..                                                ...
# 107                                       -606219.073
# 108                                       -589846.318
# 109                                      -8267696.334
# 110                                      -4155793.480
# 111                                       1081786.450
#
#      Contribution Value due to Buyers YA Latest 52 Wks  \
# 0                                           125.318534
# 1                                            15.052075
# 2                                           142.555909
# 3                                          -217.977258
# 4                                            11.085076
# ..                                                 ...
# 107                                         -29.178424
# 108                                         -12.790683
# 109                                        1442.609042
# 110                                           8.753583
# 111                                           1.734297
#
#      Contribution Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                            35.304530
# 1                                            90.889486
# 2                                          -123.763842
# 3                                            -6.084071
# 4                                            58.835005
# ..                                                 ...
# 107                                          79.085721
# 108                                          44.622348
# 109                                        -161.742549
# 110                                          19.195771
# 111                                         126.442970
#
#      Contribution Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                           -60.623195
# 1                                            -5.941635
# 2                                            81.207707
# 3                                           324.062098
# 4                                            30.079838
# ..                                                 ...
# 107                                          50.092963
# 108                                          68.168670
# 109                                       -1180.862031
# 110                                          72.050647
# 111                                         -28.177316
#
#      Contribution Value due to Buyers YA Latest 26 Wks  \
# 0                                           110.162817
# 1                                            15.856980
# 2                                            91.571016
# 3                                            76.081943
# 4                                            55.779338
# ..                                                 ...
# 107                                         -79.791661
# 108                                        -101.267852
# 109                                        -169.348673
# 110                                         -61.905636
# 111                                         -24.670119
#
#      Contribution Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                            -8.526882
# 1                                           110.355447
# 2                                           -26.054576
# 3                                             2.926710
# 4                                            16.665802
# ..                                                 ...
# 107                                          62.802325
# 108                                         124.051915
# 109                                          -3.036924
# 110                                          61.504925
# 111                                         146.363737
#
#      Contribution Value due to Value per Occasion YA Latest 26 Wks
# 0                                            -1.635942
# 1                                           -26.212446
# 2                                            34.483524
# 3                                            20.991354
# 4                                            27.554895
# ..                                                 ...
# 107                                         116.989289
# 108                                          77.215824
# 109                                         272.385734
# 110                                         100.400580
# 111                                         -21.693607
#
# [112 rows x 31 columns]

# %% [markdown]
# # pg risk

# %%
# define a helper that applies the two rules only for P&G brands
def calculate_pg_risk(row):
    if row['BRAND OWNER'] != 'PROCTER & GAMBLE':
        return 'No'                       # keep others as “No”
    l52 = row['Latest 52 vs YA']
    l26 = row['Latest 26 vs YA']

    # declining‑growth
    if l52 > 0 and l26 < l52 :
        return 'Growth Deceleration'
    # declining‑deceleration
    if l52 < 0 and l26 < l52:
        return 'Decline Acceleration'
    return 'No'

# assign the column
df_final['P&G risk'] = df_final.apply(calculate_pg_risk, axis=1)

# quick check
print(df_final['P&G risk'].value_counts())
print(df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE'][['BRAND','country',
      'Latest 52 vs YA','Latest 26 vs YA','P&G risk']].head())
# Out:
# P&G risk
# No                      8227
# Growth Deceleration       68
# Decline Acceleration      44
# Name: count, dtype: int64
#                                             BRAND       country  \
# 39                                     DON LIMPIO         Spain
# 40                                     DON LIMPIO  Total Europe
# 41    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)            GB
# 42    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)  Total Europe
# 116  ALWAYS (PROCTER & GAMBLE / PROCTER & GAMBLE)        France
#
#      Latest 52 vs YA  Latest 26 vs YA P&G risk
# 39            -0.096           -0.078       No
# 40             0.000            0.000       No
# 41             0.000            0.000       No
# 42             0.000            0.000       No
# 116            0.000            0.000       No

# %%
# RECHECK: Full verification of P&G risk logic starting with P&G data
print("="*80)
print("FULL RECHECK: LOGIC VERIFICATION")
print("="*80)

# Step 1: Filter for PROCTER & GAMBLE brands
pg_brands = df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE'].copy()
print(f"\n✓ Total P&G rows in df_final: {len(pg_brands)}")
print(f"✓ Total rows in df_final: {len(df_final)}")

# Step 2: Check P&G risk column exists
if 'P&G risk' in df_final.columns:
    print(f"✓ P&G risk column exists in df_final")
else:
    print("✗ ERROR: P&G risk column NOT found in df_final")

# Step 3: Verify logic for each risk category
print("\n" + "="*80)
print("RISK CATEGORY VERIFICATION")
print("="*80)

# Declining growth: Latest 52 > 0 AND (Latest 26 < Latest 52 OR Latest 13 < Latest 52)
declining_growth = pg_brands[
    (pg_brands['Latest 52 vs YA'] > 0) & 
    (pg_brands['Latest 26 vs YA'] < pg_brands['Latest 52 vs YA']) 
]

declining_growth_marked = pg_brands[pg_brands['P&G risk'] == 'Growth Deceleration']

print(f"\n1. DECLINING GROWTH:")
print(f"   Expected logic count: {len(declining_growth)}")
print(f"   Marked as 'Declining growth': {len(declining_growth_marked)}")
print(f"   Match: {'✓ YES' if len(declining_growth) == len(declining_growth_marked) else '✗ NO'}")

# Declining Deceleration: Latest 52 < 0 AND (Latest 26 > Latest 52 OR Latest 13 > Latest 52)
declining_deceleration = pg_brands[
    (pg_brands['Latest 52 vs YA'] < 0) & 
    (pg_brands['Latest 26 vs YA'] < pg_brands['Latest 52 vs YA']) 
]

declining_deceleration_marked = pg_brands[pg_brands['P&G risk'] == 'Decline Acceleration']

print(f"\n2. DECLINING DECELERATION:")
print(f"   Expected logic count: {len(declining_deceleration)}")
print(f"   Marked as 'Declining Deceleration': {len(declining_deceleration_marked)}")
print(f"   Match: {'✓ YES' if len(declining_deceleration) == len(declining_deceleration_marked) else '✗ NO'}")

# No risk: Everything else (including non-P&G)
no_risk_pg = pg_brands[pg_brands['P&G risk'] == 'No']
print(f"\n3. NO RISK (P&G brands only):")
print(f"   Count: {len(no_risk_pg)}")

# Step 4: Overall distribution
print("\n" + "="*80)
print("OVERALL P&G RISK DISTRIBUTION")
print("="*80)
print(df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE']['P&G risk'].value_counts())

print("\n" + "="*80)
print("NON-P&G BRANDS - SHOULD ALL BE 'No'")
print("="*80)
non_pg = df_final[df_final['BRAND OWNER']!='PROCTER & GAMBLE']
non_pg_risk_dist = non_pg['P&G risk'].value_counts()
print(non_pg_risk_dist)
if len(non_pg_risk_dist) == 1 and non_pg_risk_dist.index[0] == 'No':
    print("✓ All non-P&G brands correctly marked as 'No'")
else:
    print("✗ ERROR: Some non-P&G brands have risk values other than 'No'")

# Step 5: Sample verification rows
print("\n" + "="*80)
print("SAMPLE ROWS - DETAILED VERIFICATION")
print("="*80)

print("\nSample DECLINING GROWTH rows:")
declining_growth_sample = declining_growth_marked[['BRAND', 'country', 'Latest 52 vs YA', 'Latest 26 vs YA',  'P&G risk']].head(5)
print(declining_growth_sample)
print("Logic check (for each row, Latest 52 > 0 and min(26,13) < 52):")
for idx, row in declining_growth_sample.iterrows():
    l52 = row['Latest 52 vs YA']
    l26 = row['Latest 26 vs YA']

    print(f"  {row['BRAND']}: 52={l52:.3f} (>0?{l52>0}), 26={l26:.3f}(<52?{l26<l52})")

print("\nSample DECLINING DECELERATION rows:")
declining_deceleration_sample = declining_deceleration_marked[['BRAND', 'country', 'Latest 52 vs YA', 'Latest 26 vs YA', 'P&G risk']].head(5)
print(declining_deceleration_sample)
print("Logic check (for each row, Latest 52 < 0 and max(26,13) > 52):")
for idx, row in declining_deceleration_sample.iterrows():
    l52 = row['Latest 52 vs YA']
    l26 = row['Latest 26 vs YA']
    print(f"  {row['BRAND']}: 52={l52:.3f} (<0?{l52<0}), 26={l26:.3f}(>52?{l26>l52})")

print("\n" + "="*80)
print("VERIFICATION COMPLETE")
print("="*80)
# Out:
# ================================================================================
# FULL RECHECK: LOGIC VERIFICATION
# ================================================================================
#
# ✓ Total P&G rows in df_final: 653
# ✓ Total rows in df_final: 8339
# ✓ P&G risk column exists in df_final
#
# ================================================================================
# RISK CATEGORY VERIFICATION
# ================================================================================
#
# 1. DECLINING GROWTH:
#    Expected logic count: 68
#    Marked as 'Declining growth': 68
#    Match: ✓ YES
#
# 2. DECLINING DECELERATION:
#    Expected logic count: 44
#    Marked as 'Declining Deceleration': 44
#    Match: ✓ YES
#
# 3. NO RISK (P&G brands only):
#    Count: 541
#
# ================================================================================
# OVERALL P&G RISK DISTRIBUTION
# ================================================================================
# P&G risk
# No                      541
# Growth Deceleration      68
# Decline Acceleration     44
# Name: count, dtype: int64
#
# ================================================================================
# NON-P&G BRANDS - SHOULD ALL BE 'No'
# ================================================================================
# P&G risk
# No    7686
# Name: count, dtype: int64
# ✓ All non-P&G brands correctly marked as 'No'
#
# ================================================================================
# SAMPLE ROWS - DETAILED VERIFICATION
# ================================================================================
#
# Sample DECLINING GROWTH rows:
#                                                 BRAND  country  \
# 118      ALWAYS (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany
# 166       FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany
# 168       FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)    Spain
# 554                                           FEBREZE  Germany
# 1105  OLD SPICE (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany
#
#       Latest 52 vs YA  Latest 26 vs YA             P&G risk
# 118             0.112           -0.333  Growth Deceleration
# 166             0.024           -0.016  Growth Deceleration
# 168             3.325            0.875  Growth Deceleration
# 554             1.794           -0.433  Growth Deceleration
# 1105            0.750            0.447  Growth Deceleration
# Logic check (for each row, Latest 52 > 0 and min(26,13) < 52):
#   ALWAYS (PROCTER & GAMBLE / PROCTER & GAMBLE): 52=0.112 (>0?True), 26=-0.333(<52?True)
#   FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE): 52=0.024 (>0?True), 26=-0.016(<52?True)
#   FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE): 52=3.325 (>0?True), 26=0.875(<52?True)
#   FEBREZE: 52=1.794 (>0?True), 26=-0.433(<52?True)
#   OLD SPICE (PROCTER & GAMBLE / PROCTER & GAMBLE): 52=0.750 (>0?True), 26=0.447(<52?True)
#
# Sample DECLINING DECELERATION rows:
#                                                 BRAND  country  \
# 347            GILLETTE (PROCTER & GAMBLE / GILLETTE)    Italy
# 353                                   GILLETTE SERIES    Spain
# 356   OLD SPICE (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany
# 1318                                          SWIFFER  Germany
# 1319                                          SWIFFER    Italy
#
#       Latest 52 vs YA  Latest 26 vs YA              P&G risk
# 347            -0.086           -0.104  Decline Acceleration
# 353            -0.019           -0.063  Decline Acceleration
# 356            -0.154           -0.172  Decline Acceleration
# 1318           -1.202           -2.072  Decline Acceleration
# 1319           -0.602           -0.637  Decline Acceleration
# Logic check (for each row, Latest 52 < 0 and max(26,13) > 52):
#   GILLETTE (PROCTER & GAMBLE / GILLETTE): 52=-0.086 (<0?True), 26=-0.104(>52?False)
#   GILLETTE SERIES: 52=-0.019 (<0?True), 26=-0.063(>52?False)
#   OLD SPICE (PROCTER & GAMBLE / PROCTER & GAMBLE): 52=-0.154 (<0?True), 26=-0.172(>52?False)
#   SWIFFER: 52=-1.202 (<0?True), 26=-2.072(>52?False)
#   SWIFFER: 52=-0.602 (<0?True), 26=-0.637(>52?False)
#
# ================================================================================
# VERIFICATION COMPLETE
# ================================================================================

# %%
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347            0.000          2.819
# 1               GB          0.328            0.000          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.000          0.256
# 8336        France          0.005            0.000          0.005
# 8337            GB          0.302            0.000          0.450
# 8338  Total Europe          0.059            0.000          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration  \
# 0               0.000             Yes                  No
# 1               0.000              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335            0.000              No                  No
# 8336            0.000              No                  No
# 8337            0.000              No                  No
# 8338            0.000              No                  No
#
#      Accelerating Penetration Top Opportunity P&G risk
# 0                          No              No       No
# 1                          No              No       No
# 2                         Yes              No       No
# 3                         Yes              No       No
# 4                          No              No       No
# ...                       ...             ...      ...
# 8334                       No              No       No
# 8335                       No              No       No
# 8336                       No              No       No
# 8337                       No              No       No
# 8338                       No              No       No
#
# [8339 rows x 18 columns]

# %%
df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE']['P&G risk'].value_counts()
# Out:
# P&G risk
# No                      541
# Growth Deceleration      68
# Decline Acceleration     44
# Name: count, dtype: int64

# %%
pg_risk_final=df_final[df_final['P&G risk']!='No']
pg_risk_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 118       35  People Group      EUR  Total Panel  Total Outlets
# 166       52  People Group      EUR  Total Panel  Total Outlets
# 168       52  People Group      EUR  Total Panel  Total Outlets
# 347      117  People Group      EUR  Total Panel  Total Outlets
# 353      119  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 7786    2873  People Group      EUR  Total Panel  Total Outlets
# 8221    3030  People Group      EUR  Total Panel  Total Outlets
# 8222    3030  People Group      EUR  Total Panel  Total Outlets
# 8231    3033  People Group      EUR  Total Panel  Total Outlets
# 8244    3037  People Group      EUR  Total Panel  Total Outlets
#
#                  CATEGORY       BRAND OWNER  \
# 118          ADULT INCONT  PROCTER & GAMBLE
# 166         ADW DETERGENT  PROCTER & GAMBLE
# 168         ADW DETERGENT  PROCTER & GAMBLE
# 347           AFTER SHAVE  PROCTER & GAMBLE
# 353           AFTER SHAVE  PROCTER & GAMBLE
# ...                   ...               ...
# 7786  VITAMIN SUPPLEMENTS  PROCTER & GAMBLE
# 8221       SKIN CLEANSING  PROCTER & GAMBLE
# 8222       SKIN CLEANSING  PROCTER & GAMBLE
# 8231       SKIN CLEANSING  PROCTER & GAMBLE
# 8244       SKIN CLEANSING  PROCTER & GAMBLE
#
#                                              BRAND  country  Latest 26 Wks  \
# 118   ALWAYS (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany          3.480
# 166    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany          0.006
# 168    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)    Spain         11.064
# 347         GILLETTE (PROCTER & GAMBLE / GILLETTE)    Italy          0.020
# 353                                GILLETTE SERIES    Spain          0.000
# ...                                            ...      ...            ...
# 7786                                   VIGANTOLVIT  Germany          0.281
# 8221                           GILLETTE SATIN CARE    Italy          0.059
# 8222                           GILLETTE SATIN CARE    Spain          0.071
# 8231                              KING C. GILLETTE    Italy          0.000
# 8244                                       PAMPERS  Germany          1.214
#
#       Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA Tangible Brands  \
# 118            -0.333          5.970            0.112             Yes
# 166            -0.016          0.050            0.024              No
# 168             0.875         18.017            3.325             Yes
# 347            -0.104          0.092           -0.086              No
# 353            -0.063          0.061           -0.019              No
# ...               ...            ...              ...             ...
# 7786            0.024          0.446            0.094              No
# 8221            0.059          0.329            0.329              No
# 8222            0.056          0.177            0.135              No
# 8231           -0.026          0.024           -0.002              No
# 8244           -0.398          2.165            0.022             Yes
#
#      Growing Penetration Accelerating Penetration Top Opportunity  \
# 118                   No                       No              No
# 166                   No                       No              No
# 168                  Yes                       No              No
# 347                   No                       No              No
# 353                   No                       No              No
# ...                  ...                      ...             ...
# 7786                  No                       No              No
# 8221                  No                       No              No
# 8222                  No                       No              No
# 8231                  No                       No              No
# 8244                  No                       No              No
#
#                   P&G risk
# 118    Growth Deceleration
# 166    Growth Deceleration
# 168    Growth Deceleration
# 347   Decline Acceleration
# 353   Decline Acceleration
# ...                    ...
# 7786   Growth Deceleration
# 8221   Growth Deceleration
# 8222   Growth Deceleration
# 8231  Decline Acceleration
# 8244   Growth Deceleration
#
# [112 rows x 18 columns]

# %%
df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE'].shape
# Out:
# (653, 18)

# %%
df_final['P&G risk'].value_counts()
# Out:
# P&G risk
# No                      8227
# Growth Deceleration       68
# Decline Acceleration      44
# Name: count, dtype: int64

# %%
pg_risk_final.to_excel('pg_risk3.xlsx')

# %%
pg_risk_final.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'P&G risk'],
#       dtype='object')

# %%
pg_risk_final1=pg_risk_final[[ 'Currency',
       'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
       'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
       'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
       'Top Opportunity', 'P&G risk']]
pg_risk_final1.to_excel('pg_risk_output.xlsx',index=False)

# %%
df_priority1=df_priority[[ 'Currency', 
       'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
       'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
       'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
       'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
       'Value due to Buyers YA Latest 52 Wks',
       'Value due to Occasions per Buyer YA Latest 52 Wks',
       'Value due to Value per Occasion YA Latest 52 Wks',
       'Value vs YA (Abs Change) Latest 26 Wks',
       'Value due to Buyers YA Latest 26 Wks',
       'Value due to Occasions per Buyer YA Latest 26 Wks',
       'Value due to Value per Occasion YA Latest 26 Wks',
       'Contribution Value due to Buyers YA Latest 52 Wks',
       'Contribution Value due to Occasions per Buyer YA Latest 52 Wks',
       'Contribution Value due to Value per Occasion YA Latest 52 Wks',
       'Contribution Value due to Buyers YA Latest 26 Wks',
       'Contribution Value due to Occasions per Buyer YA Latest 26 Wks',
       'Contribution Value due to Value per Occasion YA Latest 26 Wks']]

df_priority1.to_excel('priority_brands_output.xlsx', index=False)
