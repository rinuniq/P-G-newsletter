# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# define file path and sheet names
file_path = "MAIN_Penetration and Value Drivers Template_raw data for Divyaa & Rinu v2.xlsx"
sheet1 = "Penetration Trends Template"
sheet2 = "KPIs - EU5 template"

# load both sheets skipping raw1 and assigning multi-row headers
# df1: skip first row then next 4 rows as headers
# df2: skip first row then next 2 rows as headers

df1 = pd.read_excel(
    file_path,
    sheet_name=sheet1,
   skiprows=1,
    header=[0,1,2,3]
)

df2 = pd.read_excel(
    file_path,
    sheet_name=sheet2,
    skiprows=1,
    header=[0,1]
)

# show some info
print("df1 shape:", df1.shape)
print("df1 columns:\n", df1.columns)
print("df2 shape:", df2.shape)
print("df2 columns:\n", df2.columns)
# Out:
# C:\Users\rdi5001\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)
# df1 shape: (3074, 31)
# df1 columns:
#  MultiIndex([(            'Unnamed: 0_level_0', 'Unnamed: 0_level_1', ...),
#             (            'Unnamed: 1_level_0', 'Unnamed: 1_level_1', ...),
#             (            'Unnamed: 2_level_0', 'Unnamed: 2_level_1', ...),
#             (            'Unnamed: 3_level_0', 'Unnamed: 3_level_1', ...),
#             (            'Unnamed: 4_level_0', 'Unnamed: 4_level_1', ...),
#             (            'Unnamed: 5_level_0', 'Unnamed: 5_level_1', ...),
#             (            'Unnamed: 6_level_0', 'Unnamed: 6_level_1', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             (                   'Penetration',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...),
#             ('Penetration vs YA (Abs Change)',       'Total Europe', ...)],
#            )
# df2 shape: (5265, 18)
# df2 columns:
#  MultiIndex([(        'Unnamed: 0_level_0', ...),
#             (        'Unnamed: 1_level_0', ...),
#             (        'Unnamed: 2_level_0', ...),
#             (        'Unnamed: 3_level_0', ...),
#             (        'Unnamed: 4_level_0', ...),
#             (        'Unnamed: 5_level_0', ...),
#             (        'Unnamed: 6_level_0', ...),
#             (        'Unnamed: 7_level_0', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 52 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...),
#             ('Latest 26 Wks - w/e W4 Y26', ...)],
#            )
# C:\Users\rdi5001\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)

# %%
df1
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0    Unnamed: 5_level_0  \
#      Unnamed: 3_level_1 Unnamed: 4_level_1    Unnamed: 5_level_1
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_0                Penetration  \
#                    Unnamed: 6_level_1               Total Europe
#                    Unnamed: 6_level_2         Unnamed: 7_level_2
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                             \
#
#              Unnamed: 8_level_2                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                 Penetration vs YA (Abs Change)  \
#                                                   Total Europe
#                                            Unnamed: 19_level_2
#      Latest 26 Wks - w/e W4 Y26     Latest 52 Wks - w/e W4 Y26
# 0                         7.331                         -0.216
# 1                         5.643                          1.210
# 2                         0.860                          0.016
# 3                           NaN                         -0.102
# 4                           NaN                         -0.001
# ...                         ...                            ...
# 3069                      0.002                         -0.048
# 3070                        NaN                         -0.025
# 3071                      0.002                          0.000
# 3072                        NaN                         -0.014
# 3073                        NaN                          0.087
#
#                                                             \
#
#             Unnamed: 20_level_2                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
df1
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0    Unnamed: 5_level_0  \
#      Unnamed: 3_level_1 Unnamed: 4_level_1    Unnamed: 5_level_1
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_0                Penetration  \
#                    Unnamed: 6_level_1               Total Europe
#                    Unnamed: 6_level_2         Unnamed: 7_level_2
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                             \
#
#              Unnamed: 8_level_2                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                 Penetration vs YA (Abs Change)  \
#                                                   Total Europe
#                                            Unnamed: 19_level_2
#      Latest 26 Wks - w/e W4 Y26     Latest 52 Wks - w/e W4 Y26
# 0                         7.331                         -0.216
# 1                         5.643                          1.210
# 2                         0.860                          0.016
# 3                           NaN                         -0.102
# 4                           NaN                         -0.001
# ...                         ...                            ...
# 3069                      0.002                         -0.048
# 3070                        NaN                         -0.025
# 3071                      0.002                          0.000
# 3072                        NaN                         -0.014
# 3073                        NaN                          0.087
#
#                                                             \
#
#             Unnamed: 20_level_2                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
# Replace Unnamed columns in the 3rd header level (level index 2) after column 7 with 'Total Europe'
if isinstance(df1.columns, pd.MultiIndex):
    cols = list(df1.columns)
    new_cols = []
    for i, col in enumerate(cols):
        col_list = list(col)
        if i >= 7 and len(col_list) > 2 and isinstance(col_list[2], str) and col_list[2].startswith('Unnamed'):
            col_list[2] = col_list[1]
        new_cols.append(tuple(col_list))
    df1.columns = pd.MultiIndex.from_tuples(new_cols)

# display updated dataframe
df1
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#      Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0    Unnamed: 5_level_0  \
#      Unnamed: 3_level_1 Unnamed: 4_level_1    Unnamed: 5_level_1
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_0                Penetration  \
#                    Unnamed: 6_level_1               Total Europe
#                    Unnamed: 6_level_2               Total Europe
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                             \
#
#                                                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                 Penetration vs YA (Abs Change)  \
#                                                   Total Europe
#                                                   Total Europe
#      Latest 26 Wks - w/e W4 Y26     Latest 52 Wks - w/e W4 Y26
# 0                         7.331                         -0.216
# 1                         5.643                          1.210
# 2                         0.860                          0.016
# 3                           NaN                         -0.102
# 4                           NaN                         -0.001
# ...                         ...                            ...
# 3069                      0.002                         -0.048
# 3070                        NaN                         -0.025
# 3071                      0.002                          0.000
# 3072                        NaN                         -0.014
# 3073                        NaN                          0.087
#
#                                                             \
#
#                                                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                             \
#
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                             \
#
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                             \
#
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
# Create a new view of df1 keeping header levels 1, 3, and 4 (human numbering)
# -> which are 0-based levels 0, 2, and 3 in pandas
if isinstance(df1.columns, pd.MultiIndex) and df1.columns.nlevels >= 1:
    nlevels = df1.columns.nlevels
 
    # Desired keep-levels (0-based): keep 1st, 3rd, 4th -> [0, 2, 3]
    keep_levels = [lvl for lvl in [0, 2, 3] if lvl < nlevels]
 
    # If nothing to drop (e.g., not enough levels), just copy
    if len(keep_levels) == nlevels:
        df1_trimmed = df1.copy()
    else:
        drop_levels = [lvl for lvl in range(nlevels) if lvl not in keep_levels]
        df1_trimmed = df1.copy()
        df1_trimmed.columns = df1_trimmed.columns.droplevel(drop_levels)
else:
    df1_trimmed = df1.copy()
 
df1_trimmed
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#      Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
#                  People           Currency        Total Panel
# 0          People Group                EUR        Total Panel
# 1          People Group                EUR        Total Panel
# 2          People Group                EUR        Total Panel
# 3          People Group                EUR        Total Panel
# 4          People Group                EUR        Total Panel
# ...                 ...                ...                ...
# 3069       People Group                EUR        Total Panel
# 3070       People Group                EUR        Total Panel
# 3071       People Group                EUR        Total Panel
# 3072       People Group                EUR        Total Panel
# 3073       People Group                EUR        Total Panel
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0    Unnamed: 5_level_0  \
#      Unnamed: 3_level_2 Unnamed: 4_level_2    Unnamed: 5_level_2
#           Total Outlets           CATEGORY           BRAND OWNER
# 0         Total Outlets   ABRASIVE CL PADS                    3M
# 1         Total Outlets   ABRASIVE CL PADS             ALL OTHER
# 2         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 3         Total Outlets   ABRASIVE CL PADS     COLGATE PALMOLIVE
# 4         Total Outlets   ABRASIVE CL PADS           FREUDENBERG
# ...                 ...                ...                   ...
# 3069      Total Outlets     SKIN CLEANSING                WELEDA
# 3070      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3071      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3072      Total Outlets     SKIN CLEANSING  YELLOW WOOD PARTNERS
# 3073      Total Outlets     SKIN CLEANSING             ZURU EDGE
#
#                    Unnamed: 6_level_0                Penetration  \
#                    Unnamed: 6_level_2               Total Europe
#                                 BRAND Latest 52 Wks - w/e W4 Y26
# 0                        SCOTCH BRITE                      3.912
# 1                           ALL OTHER                     18.583
# 2            AJAX (COLGATE PALMOLIVE)                      0.193
# 3           BRAVO (COLGATE PALMOLIVE)                      0.825
# 4              MARIGOLD (FREUDENBERG)                      0.054
# ...                               ...                        ...
# 3069                           WELEDA                      0.106
# 3070                           FISSAN                      0.088
# 3071     PONDS (YELLOW WOOD PARTNERS)                      0.002
# 3072  ST. IVES (YELLOW WOOD PARTNERS)                      0.256
# 3073                DAISE (ZURU EDGE)                      0.087
#
#                                                             \
#                                                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         2.304                      2.819
# 1                        11.894                     29.041
# 2                         0.104                        NaN
# 3                         0.502                        NaN
# 4                         0.028                        NaN
# ...                         ...                        ...
# 3069                      0.078                        NaN
# 3070                      0.048                        NaN
# 3071                      0.001                        NaN
# 3072                      0.160                        NaN
# 3073                      0.059                      0.005
#
#                                                             \
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         1.347                      0.578
# 1                        19.432                     25.447
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                      0.279
# ...                         ...                        ...
# 3069                        NaN                      0.089
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                      1.327
# 3073                      0.005                      0.450
#
#                                                             \
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.328                      0.025
# 1                        16.651                      8.716
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                         0.145                        NaN
# ...                         ...                        ...
# 3069                      0.052                      0.207
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.832                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                      6.966
# 1                         5.621                     24.480
# 2                           NaN                        NaN
# 3                           NaN                      3.350
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.162                      0.085
# 3070                        NaN                      0.523
# 3071                        NaN                        NaN
# 3072                        NaN                      0.008
# 3073                        NaN                        NaN
#
#                                                             \
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         4.423                     12.530
# 1                        15.143                     10.364
# 2                           NaN                      1.590
# 3                         2.184                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.034
# 3070                      0.289                        NaN
# 3071                        NaN                      0.011
# 3072                      0.005                        NaN
# 3073                        NaN                        NaN
#
#                                 Penetration vs YA (Abs Change)  \
#                                                   Total Europe
#      Latest 26 Wks - w/e W4 Y26     Latest 52 Wks - w/e W4 Y26
# 0                         7.331                         -0.216
# 1                         5.643                          1.210
# 2                         0.860                          0.016
# 3                           NaN                         -0.102
# 4                           NaN                         -0.001
# ...                         ...                            ...
# 3069                      0.002                         -0.048
# 3070                        NaN                         -0.025
# 3071                      0.002                          0.000
# 3072                        NaN                         -0.014
# 3073                        NaN                          0.087
#
#                                                             \
#                                                     France
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                     -0.251000                     -0.136
# 1                      0.627000                      3.909
# 2                     -0.001000                     -0.006
# 3                     -0.071000                        NaN
# 4                     -0.004000                        NaN
# ...                         ...                        ...
# 3069                  -0.004000                        NaN
# 3070                  -0.031000                        NaN
# 3071                   0.000071                        NaN
# 3072                   0.011000                        NaN
# 3073                   0.059000                      0.005
#
#                                                             \
#                                                         GB
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.365                     -0.170
# 1                         1.383                      1.192
# 2                        -0.006                        NaN
# 3                           NaN                        NaN
# 4                           NaN                     -0.006
# ...                         ...                        ...
# 3069                        NaN                      0.035
# 3070                        NaN                        NaN
# 3071                        NaN                      0.005
# 3072                        NaN                     -0.072
# 3073                      0.005                      0.450
#
#                                                             \
#                                                    Germany
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.083                      0.000
# 1                         0.843                      0.877
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                        -0.022                        NaN
# ...                         ...                        ...
# 3069                      0.016                     -0.234
# 3070                        NaN                        NaN
# 3071                      0.005                        NaN
# 3072                      0.058                        NaN
# 3073                      0.302                        NaN
#
#                                                             \
#                                                      Italy
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                         0.025                     -1.439
# 1                         1.342                      1.566
# 2                           NaN                        NaN
# 3                           NaN                      0.180
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                     -0.088                      0.053
# 3070                        NaN                     -0.147
# 3071                        NaN                        NaN
# 3072                        NaN                      0.000
# 3073                        NaN                        NaN
#
#                                                             \
#                                                      Spain
#      Latest 26 Wks - w/e W4 Y26 Latest 52 Wks - w/e W4 Y26
# 0                        -0.775                      0.306
# 1                         0.724                     -1.347
# 2                           NaN                      0.139
# 3                         0.290                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 3069                      0.076                      0.008
# 3070                     -0.185                        NaN
# 3071                        NaN                     -0.005
# 3072                     -0.004                        NaN
# 3073                        NaN                        NaN
#
#
#
#      Latest 26 Wks - w/e W4 Y26
# 0                        -0.282
# 1                        -1.591
# 2                        -0.001
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3069                      0.002
# 3070                        NaN
# 3071                     -0.008
# 3072                        NaN
# 3073                        NaN
#
# [3074 rows x 31 columns]

# %%
# alternative transformation using melt, treating first 7 columns as metadata
# use df_base from earlier steps

df_base = df1_trimmed

 
# determine metadata and data columns by position
metadata_cols = list(df_base.columns[:7])
# we'll slice by position for data rather than by labels
data_cols_raw = list(df_base.columns[7:])
 
print("Metadata cols:", metadata_cols)
print("First few raw data cols:", data_cols_raw[:5])
 
# --- RENAMING RULE (updated) ---
# Rename the header2 (metric) by appending " vs YA" **iff** the string "YA" is present in header0 (Header0).
# Works for 2- or 3-level MultiIndex columns; your case is 3-level: (Header0, Header1/Country, Header2/Metric).
nlevels = getattr(df_base.columns, "nlevels", 1)
 
renamed_data = []
for col in data_cols_raw:
    if isinstance(col, tuple):
        if nlevels >= 3 and len(col) >= 3:
            head0, country, metric = col[0], col[1], col[2]
        elif len(col) == 2:
            head0, country, metric = col[0], col[0], col[1]
        else:
            head0 = col[0] if len(col) >= 1 else ""
            country = col[-2] if len(col) >= 2 else ""
            metric = col[-1] if len(col) >= 1 else col
    else:
        head0, country, metric = "", "", col
 
    # If header0 contains "YA", append " vs YA" to the metric name
    if "YA" in str(head0).upper():
        metric = f"{metric} vs YA"
 
    renamed_data.append((country, metric))
 
# slice the data portion of df_base and then rename its columns
df_data = df_base.iloc[:, 7:].copy()
df_data.columns = pd.MultiIndex.from_tuples(renamed_data)
 
# also extract df_meta for later use
df_meta = df_base.iloc[:, :7].copy()
 
# ---- IMPORTANT CHANGE: use the LAST LEVEL for meta names (Header2) ----
# This yields: People, Currency, Total Panel, Total Outlets, CATEGORY, BRAND OWNER, BRAND
def _last_level_name(col):
    if isinstance(col, tuple):
        return col[-1]
    return col
 
meta_display_names = [_last_level_name(col) for col in metadata_cols]
 
# flatten df_data columns
flat_cols = [f"{c0}|||{c1}" for c0, c1 in renamed_data]
df_flat = df_data.copy()
df_flat.columns = flat_cols
 
# add meta columns to flat using LAST LEVEL names
for col, disp in zip(metadata_cols, meta_display_names):
    df_flat[f"meta|||{disp}"] = df_meta[col].squeeze().values
 
# preserve row identifier
df_flat = df_flat.reset_index(drop=True)
df_flat['row_id'] = df_flat.index
 
# melt on metric columns
id_vars = ['row_id'] + [f"meta|||{disp}" for disp in meta_display_names]
df_melt = df_flat.melt(id_vars=id_vars, var_name='combined', value_name='value')
 
# split combined into country and metric
split_cols = df_melt['combined'].str.split('\\|\\|\\|', expand=True)
df_melt['country'] = split_cols[0]
df_melt['metric'] = split_cols[1]
 
# pivot back
df_final = df_melt.pivot_table(
    index=id_vars + ['country'],
    columns='metric',
    values='value',
    aggfunc='first'
).reset_index()
 
# clean metadata column names: remove the "meta|||" prefix using the same display names
for disp in meta_display_names:
    df_final = df_final.rename(columns={f"meta|||{disp}": disp})
 
print("Transformed final shape:", df_final.shape)
df_final
# Out:
# Metadata cols: [('Unnamed: 0_level_0', 'Unnamed: 0_level_2', 'People'), ('Unnamed: 1_level_0', 'Unnamed: 1_level_2', 'Currency'), ('Unnamed: 2_level_0', 'Unnamed: 2_level_2', 'Total Panel'), ('Unnamed: 3_level_0', 'Unnamed: 3_level_2', 'Total Outlets'), ('Unnamed: 4_level_0', 'Unnamed: 4_level_2', 'CATEGORY'), ('Unnamed: 5_level_0', 'Unnamed: 5_level_2', 'BRAND OWNER'), ('Unnamed: 6_level_0', 'Unnamed: 6_level_2', 'BRAND')]
# First few raw data cols: [('Penetration', 'Total Europe', 'Latest 52 Wks - w/e W4 Y26'), ('Penetration', 'Total Europe', 'Latest 26 Wks - w/e W4 Y26'), ('Penetration', 'France', 'Latest 52 Wks - w/e W4 Y26'), ('Penetration', 'France', 'Latest 26 Wks - w/e W4 Y26'), ('Penetration', 'GB', 'Latest 52 Wks - w/e W4 Y26')]
# Transformed final shape: (8339, 13)
# metric  row_id        People Currency  Total Panel  Total Outlets  \
# 0            0  People Group      EUR  Total Panel  Total Outlets
# 1            0  People Group      EUR  Total Panel  Total Outlets
# 2            0  People Group      EUR  Total Panel  Total Outlets
# 3            0  People Group      EUR  Total Panel  Total Outlets
# 4            0  People Group      EUR  Total Panel  Total Outlets
# ...        ...           ...      ...          ...            ...
# 8334      3072  People Group      EUR  Total Panel  Total Outlets
# 8335      3072  People Group      EUR  Total Panel  Total Outlets
# 8336      3073  People Group      EUR  Total Panel  Total Outlets
# 8337      3073  People Group      EUR  Total Panel  Total Outlets
# 8338      3073  People Group      EUR  Total Panel  Total Outlets
#
# metric          CATEGORY           BRAND OWNER  \
# 0       ABRASIVE CL PADS                    3M
# 1       ABRASIVE CL PADS                    3M
# 2       ABRASIVE CL PADS                    3M
# 3       ABRASIVE CL PADS                    3M
# 4       ABRASIVE CL PADS                    3M
# ...                  ...                   ...
# 8334      SKIN CLEANSING  YELLOW WOOD PARTNERS
# 8335      SKIN CLEANSING  YELLOW WOOD PARTNERS
# 8336      SKIN CLEANSING             ZURU EDGE
# 8337      SKIN CLEANSING             ZURU EDGE
# 8338      SKIN CLEANSING             ZURU EDGE
#
# metric                            BRAND       country  \
# 0                          SCOTCH BRITE        France
# 1                          SCOTCH BRITE            GB
# 2                          SCOTCH BRITE       Germany
# 3                          SCOTCH BRITE         Italy
# 4                          SCOTCH BRITE         Spain
# ...                                 ...           ...
# 8334    ST. IVES (YELLOW WOOD PARTNERS)         Italy
# 8335    ST. IVES (YELLOW WOOD PARTNERS)  Total Europe
# 8336                  DAISE (ZURU EDGE)        France
# 8337                  DAISE (ZURU EDGE)            GB
# 8338                  DAISE (ZURU EDGE)  Total Europe
#
# metric  Latest 26 Wks - w/e W4 Y26  Latest 26 Wks - w/e W4 Y26 vs YA  \
# 0                            1.347                            -0.365
# 1                            0.328                            -0.083
# 2                            0.025                             0.025
# 3                            4.423                            -0.775
# 4                            7.331                            -0.282
# ...                            ...                               ...
# 8334                         0.005                            -0.004
# 8335                         0.160                             0.011
# 8336                         0.005                             0.005
# 8337                         0.302                             0.302
# 8338                         0.059                             0.059
#
# metric  Latest 52 Wks - w/e W4 Y26  Latest 52 Wks - w/e W4 Y26 vs YA
# 0                            2.819                            -0.136
# 1                            0.578                            -0.170
# 2                            0.025                             0.000
# 3                            6.966                            -1.439
# 4                           12.530                             0.306
# ...                            ...                               ...
# 8334                         0.008                             0.000
# 8335                         0.256                            -0.014
# 8336                         0.005                             0.005
# 8337                         0.450                             0.450
# 8338                         0.087                             0.087
#
# [8339 rows x 13 columns]

# %%
df_final
# Out:
# metric  row_id        People Currency  Total Panel  Total Outlets  \
# 0            0  People Group      EUR  Total Panel  Total Outlets
# 1            0  People Group      EUR  Total Panel  Total Outlets
# 2            0  People Group      EUR  Total Panel  Total Outlets
# 3            0  People Group      EUR  Total Panel  Total Outlets
# 4            0  People Group      EUR  Total Panel  Total Outlets
# ...        ...           ...      ...          ...            ...
# 8334      3072  People Group      EUR  Total Panel  Total Outlets
# 8335      3072  People Group      EUR  Total Panel  Total Outlets
# 8336      3073  People Group      EUR  Total Panel  Total Outlets
# 8337      3073  People Group      EUR  Total Panel  Total Outlets
# 8338      3073  People Group      EUR  Total Panel  Total Outlets
#
# metric          CATEGORY           BRAND OWNER  \
# 0       ABRASIVE CL PADS                    3M
# 1       ABRASIVE CL PADS                    3M
# 2       ABRASIVE CL PADS                    3M
# 3       ABRASIVE CL PADS                    3M
# 4       ABRASIVE CL PADS                    3M
# ...                  ...                   ...
# 8334      SKIN CLEANSING  YELLOW WOOD PARTNERS
# 8335      SKIN CLEANSING  YELLOW WOOD PARTNERS
# 8336      SKIN CLEANSING             ZURU EDGE
# 8337      SKIN CLEANSING             ZURU EDGE
# 8338      SKIN CLEANSING             ZURU EDGE
#
# metric                            BRAND       country  \
# 0                          SCOTCH BRITE        France
# 1                          SCOTCH BRITE            GB
# 2                          SCOTCH BRITE       Germany
# 3                          SCOTCH BRITE         Italy
# 4                          SCOTCH BRITE         Spain
# ...                                 ...           ...
# 8334    ST. IVES (YELLOW WOOD PARTNERS)         Italy
# 8335    ST. IVES (YELLOW WOOD PARTNERS)  Total Europe
# 8336                  DAISE (ZURU EDGE)        France
# 8337                  DAISE (ZURU EDGE)            GB
# 8338                  DAISE (ZURU EDGE)  Total Europe
#
# metric  Latest 26 Wks - w/e W4 Y26  Latest 26 Wks - w/e W4 Y26 vs YA  \
# 0                            1.347                            -0.365
# 1                            0.328                            -0.083
# 2                            0.025                             0.025
# 3                            4.423                            -0.775
# 4                            7.331                            -0.282
# ...                            ...                               ...
# 8334                         0.005                            -0.004
# 8335                         0.160                             0.011
# 8336                         0.005                             0.005
# 8337                         0.302                             0.302
# 8338                         0.059                             0.059
#
# metric  Latest 52 Wks - w/e W4 Y26  Latest 52 Wks - w/e W4 Y26 vs YA
# 0                            2.819                            -0.136
# 1                            0.578                            -0.170
# 2                            0.025                             0.000
# 3                            6.966                            -1.439
# 4                           12.530                             0.306
# ...                            ...                               ...
# 8334                         0.008                             0.000
# 8335                         0.256                            -0.014
# 8336                         0.005                             0.005
# 8337                         0.450                             0.450
# 8338                         0.087                             0.087
#
# [8339 rows x 13 columns]

# %%
df_final.columns=['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
       'CATEGORY', 'BRAND OWNER', 'BRAND', 'country',
       'Latest 26 Wks', 'Latest 26 vs YA',
       'Latest 52 Wks', 'Latest 52 vs YA']

# %%
df_final = df_final.fillna(0)

print("NaN values after filling:")
print(df_final.isna().sum())
# Out:
# NaN values after filling:
# row_id             0
# People             0
# Currency           0
# Total Panel        0
# Total Outlets      0
# CATEGORY           0
# BRAND OWNER        0
# BRAND              0
# country            0
# Latest 26 Wks      0
# Latest 26 vs YA    0
# Latest 52 Wks      0
# Latest 52 vs YA    0
# dtype: int64

# %% [markdown]
# # >2pp

# %%
tangible_threshold = 2
df_final['Tangible Brands'] = df_final['Latest 52 Wks'].apply(lambda x: 'Yes' if x > tangible_threshold else 'No')

# display a sample
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347           -0.365          2.819
# 1               GB          0.328           -0.083          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.011          0.256
# 8336        France          0.005            0.005          0.005
# 8337            GB          0.302            0.302          0.450
# 8338  Total Europe          0.059            0.059          0.087
#
#       Latest 52 vs YA Tangible Brands
# 0              -0.136             Yes
# 1              -0.170              No
# 2               0.000              No
# 3              -1.439             Yes
# 4               0.306             Yes
# ...               ...             ...
# 8334            0.000              No
# 8335           -0.014              No
# 8336            0.005              No
# 8337            0.450              No
# 8338            0.087              No
#
# [8339 rows x 14 columns]

# %%
df_final.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands'],
#       dtype='object')

# %% [markdown]
# # Growing penetration, Latest 26w vs year ago should be greater than .2

# %%
growing_threshold = 0.2
df_final['Growing Penetration'] = df_final['Latest 26 vs YA'].apply(lambda x: 'Yes' if x > growing_threshold else 'No')

df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347           -0.365          2.819
# 1               GB          0.328           -0.083          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.011          0.256
# 8336        France          0.005            0.005          0.005
# 8337            GB          0.302            0.302          0.450
# 8338  Total Europe          0.059            0.059          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration
# 0              -0.136             Yes                  No
# 1              -0.170              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335           -0.014              No                  No
# 8336            0.005              No                  No
# 8337            0.450              No                 Yes
# 8338            0.087              No                  No
#
# [8339 rows x 15 columns]

# %%
df_final['Growing Penetration'].value_counts()
# Out:
# Growing Penetration
# No     7636
# Yes     703
# Name: count, dtype: int64

# %% [markdown]
# # Accelerating Penetration
# - Penetration growth in latest 26 weeks vs YA  is greater than penetration change in latest 52. Consider only YA.

# %%
df_final['Accelerating Penetration'] = (df_final['Latest 26 vs YA'] > df_final['Latest 52 vs YA']).apply(lambda x: 'Yes' if x else 'No')

df_final[['BRAND', 'country', 'Latest 26 vs YA', 'Latest 52 vs YA', 'Accelerating Penetration']].head(10)
# Out:
#           BRAND       country  Latest 26 vs YA  Latest 52 vs YA  \
# 0  SCOTCH BRITE        France           -0.365           -0.136
# 1  SCOTCH BRITE            GB           -0.083           -0.170
# 2  SCOTCH BRITE       Germany            0.025            0.000
# 3  SCOTCH BRITE         Italy           -0.775           -1.439
# 4  SCOTCH BRITE         Spain           -0.282            0.306
# 5  SCOTCH BRITE  Total Europe           -0.251           -0.216
# 6     ALL OTHER        France            1.383            3.909
# 7     ALL OTHER            GB            0.843            1.192
# 8     ALL OTHER       Germany            1.342            0.877
# 9     ALL OTHER         Italy            0.724            1.566
#
#   Accelerating Penetration
# 0                       No
# 1                      Yes
# 2                      Yes
# 3                      Yes
# 4                       No
# 5                       No
# 6                       No
# 7                       No
# 8                      Yes
# 9                       No

# %%
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347           -0.365          2.819
# 1               GB          0.328           -0.083          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.011          0.256
# 8336        France          0.005            0.005          0.005
# 8337            GB          0.302            0.302          0.450
# 8338  Total Europe          0.059            0.059          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration  \
# 0              -0.136             Yes                  No
# 1              -0.170              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335           -0.014              No                  No
# 8336            0.005              No                  No
# 8337            0.450              No                 Yes
# 8338            0.087              No                  No
#
#      Accelerating Penetration
# 0                          No
# 1                         Yes
# 2                         Yes
# 3                         Yes
# 4                          No
# ...                       ...
# 8334                       No
# 8335                      Yes
# 8336                       No
# 8337                       No
# 8338                       No
#
# [8339 rows x 16 columns]

# %%
df_final['Top Opportunity'] = (
    (df_final['Tangible Brands'] == 'Yes') & 
    (df_final['Growing Penetration'] == 'Yes') & 
    (df_final['Accelerating Penetration'] == 'Yes')
).apply(lambda x: 'Yes' if x else 'No')

# display sample with all columns
df_final[['BRAND', 'country', 'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration', 'Top Opportunity']].head(10)
# Out:
#           BRAND       country Tangible Brands Growing Penetration  \
# 0  SCOTCH BRITE        France             Yes                  No
# 1  SCOTCH BRITE            GB              No                  No
# 2  SCOTCH BRITE       Germany              No                  No
# 3  SCOTCH BRITE         Italy             Yes                  No
# 4  SCOTCH BRITE         Spain             Yes                  No
# 5  SCOTCH BRITE  Total Europe             Yes                  No
# 6     ALL OTHER        France             Yes                 Yes
# 7     ALL OTHER            GB             Yes                 Yes
# 8     ALL OTHER       Germany             Yes                 Yes
# 9     ALL OTHER         Italy             Yes                 Yes
#
#   Accelerating Penetration Top Opportunity
# 0                       No              No
# 1                      Yes              No
# 2                      Yes              No
# 3                      Yes              No
# 4                       No              No
# 5                       No              No
# 6                       No              No
# 7                       No              No
# 8                      Yes             Yes
# 9                       No              No

# %%
Top_Oppurtunity=df_final[df_final['Top Opportunity']=='Yes']
Top_Oppurtunity
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 8          1  People Group      EUR  Total Panel  Total Outlets
# 15         3  People Group      EUR  Total Panel  Total Outlets
# 21         5  People Group      EUR  Total Panel  Total Outlets
# 30         7  People Group      EUR  Total Panel  Total Outlets
# 61        18  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 7815    2887  People Group      EUR  Total Panel  Total Outlets
# 7866    2903  People Group      EUR  Total Panel  Total Outlets
# 8055    2974  People Group      EUR  Total Panel  Total Outlets
# 8106    2988  People Group      EUR  Total Panel  Total Outlets
# 8133    2998  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY        BRAND OWNER                      BRAND  country  \
# 8     ABRASIVE CL PADS          ALL OTHER                  ALL OTHER  Germany
# 15    ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)    Italy
# 21    ABRASIVE CL PADS        FREUDENBERG                     VILEDA  Germany
# 30    ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX    Italy
# 61        ADULT INCONT             ESSITY              TENA (ESSITY)       GB
# ...                ...                ...                        ...      ...
# 7815    SKIN CLEANSING          ALL OTHER                  ALL OTHER       GB
# 7866    SKIN CLEANSING       BOLTON GROUP            ACQUA ALLE ROSE    Italy
# 8055    SKIN CLEANSING     KIMBERLY CLARK                    HUGGIES    Italy
# 8106    SKIN CLEANSING            L'OREAL   MIXA (L'OREAL / L'OREAL)   France
# 8133    SKIN CLEANSING         LEA NATURE                SO'BIO ETIC   France
#
#       Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 8             5.621            1.342          8.716            0.877
# 15            2.184            0.290          3.350            0.180
# 21            4.371            0.630          6.745            0.319
# 30           11.639            1.371         17.913            0.985
# 61           10.823            1.357         12.955            0.586
# ...             ...              ...            ...              ...
# 7815         17.044            0.747         25.194            0.107
# 7866          1.817            0.391          3.015            0.164
# 8055          1.356            0.337          2.063            0.259
# 8106          5.101            0.223          7.754            0.194
# 8133          1.536            0.252          2.637            0.177
#
#      Tangible Brands Growing Penetration Accelerating Penetration  \
# 8                Yes                 Yes                      Yes
# 15               Yes                 Yes                      Yes
# 21               Yes                 Yes                      Yes
# 30               Yes                 Yes                      Yes
# 61               Yes                 Yes                      Yes
# ...              ...                 ...                      ...
# 7815             Yes                 Yes                      Yes
# 7866             Yes                 Yes                      Yes
# 8055             Yes                 Yes                      Yes
# 8106             Yes                 Yes                      Yes
# 8133             Yes                 Yes                      Yes
#
#      Top Opportunity
# 8                Yes
# 15               Yes
# 21               Yes
# 30               Yes
# 61               Yes
# ...              ...
# 7815             Yes
# 7866             Yes
# 8055             Yes
# 8106             Yes
# 8133             Yes
#
# [210 rows x 17 columns]

# %% [markdown]
# # df2

# %%
# Process df2: Keep MultiIndex to properly extract header0 and header1
df2_copy = df2.copy()

print("df2 original columns (first 12):", df2_copy.columns[:12].tolist())
print("df2 MultiIndex nlevels:", df2_copy.columns.nlevels)

# Identify metadata columns (first 8 by position)
metadata_cols = list(df2_copy.columns[:8])
data_cols = list(df2_copy.columns[8:])

print("\nMetadata columns:", metadata_cols)
print("Data columns count:", len(data_cols))
print("Data columns sample (tuples):", data_cols[:5])

# Process the data columns: extract header0 (time period) + header1 (metric)
renamed_cols = []

for col in data_cols:
    h0, h1 = col[0], col[1]  # col is a tuple (header0, header1)
    
    # Split header0 at '-' and take the first part
    time_period = h0.split('-')[0].strip()
    
    # Combine metric + time period
    new_col = f"{h1} {time_period}"
    renamed_cols.append(new_col)

print("\nRenamed data columns (first 10):", renamed_cols[:10])

# Create new dataframe with renamed columns
df2_meta = df2_copy.iloc[:, :8].copy()
df2_data = df2_copy.iloc[:, 8:].copy()

# Flatten column names to single level
df2_meta.columns = [col[1] for col in df2_meta.columns]
df2_data.columns = renamed_cols

# Concatenate metadata and data
df2_processed = pd.concat([df2_meta, df2_data], axis=1)

print("\ndf2_processed shape:", df2_processed.shape)
print("df2_processed columns:", df2_processed.columns.tolist())
print("\nSample of df2_processed:")
df2_processed
# Out:
# df2 original columns (first 12): [('Unnamed: 0_level_0', 'People'), ('Unnamed: 1_level_0', 'Currency'), ('Unnamed: 2_level_0', 'Total Panel'), ('Unnamed: 3_level_0', 'Total Outlets'), ('Unnamed: 4_level_0', 'Countries'), ('Unnamed: 5_level_0', 'CATEGORY'), ('Unnamed: 6_level_0', 'BRAND OWNER'), ('Unnamed: 7_level_0', 'BRAND'), ('Latest 52 Wks - w/e W4 Y26', 'Penetration'), ('Latest 52 Wks - w/e W4 Y26', 'Value vs YA (Abs Change)'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Buyers YA'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Occasions per Buyer YA')]
# df2 MultiIndex nlevels: 2
#
# Metadata columns: [('Unnamed: 0_level_0', 'People'), ('Unnamed: 1_level_0', 'Currency'), ('Unnamed: 2_level_0', 'Total Panel'), ('Unnamed: 3_level_0', 'Total Outlets'), ('Unnamed: 4_level_0', 'Countries'), ('Unnamed: 5_level_0', 'CATEGORY'), ('Unnamed: 6_level_0', 'BRAND OWNER'), ('Unnamed: 7_level_0', 'BRAND')]
# Data columns count: 10
# Data columns sample (tuples): [('Latest 52 Wks - w/e W4 Y26', 'Penetration'), ('Latest 52 Wks - w/e W4 Y26', 'Value vs YA (Abs Change)'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Buyers YA'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Occasions per Buyer YA'), ('Latest 52 Wks - w/e W4 Y26', 'Value due to Value per Occasion YA')]
#
# Renamed data columns (first 10): ['Penetration Latest 52 Wks', 'Value vs YA (Abs Change) Latest 52 Wks', 'Value due to Buyers YA Latest 52 Wks', 'Value due to Occasions per Buyer YA Latest 52 Wks', 'Value due to Value per Occasion YA Latest 52 Wks', 'Penetration Latest 26 Wks', 'Value vs YA (Abs Change) Latest 26 Wks', 'Value due to Buyers YA Latest 26 Wks', 'Value due to Occasions per Buyer YA Latest 26 Wks', 'Value due to Value per Occasion YA Latest 26 Wks']
#
# df2_processed shape: (5265, 18)
# df2_processed columns: ['People', 'Currency', 'Total Panel', 'Total Outlets', 'Countries', 'CATEGORY', 'BRAND OWNER', 'BRAND', 'Penetration Latest 52 Wks', 'Value vs YA (Abs Change) Latest 52 Wks', 'Value due to Buyers YA Latest 52 Wks', 'Value due to Occasions per Buyer YA Latest 52 Wks', 'Value due to Value per Occasion YA Latest 52 Wks', 'Penetration Latest 26 Wks', 'Value vs YA (Abs Change) Latest 26 Wks', 'Value due to Buyers YA Latest 26 Wks', 'Value due to Occasions per Buyer YA Latest 26 Wks', 'Value due to Value per Occasion YA Latest 26 Wks']
#
# Sample of df2_processed:
#             People Currency  Total Panel  Total Outlets Countries  \
# 0     People Group      EUR  Total Panel  Total Outlets    France
# 1     People Group      EUR  Total Panel  Total Outlets    France
# 2     People Group      EUR  Total Panel  Total Outlets    France
# 3     People Group      EUR  Total Panel  Total Outlets    France
# 4     People Group      EUR  Total Panel  Total Outlets    France
# ...            ...      ...          ...            ...       ...
# 5260  People Group      EUR  Total Panel  Total Outlets     Spain
# 5261  People Group      EUR  Total Panel  Total Outlets     Spain
# 5262  People Group      EUR  Total Panel  Total Outlets     Spain
# 5263  People Group      EUR  Total Panel  Total Outlets     Spain
# 5264  People Group      EUR  Total Panel  Total Outlets     Spain
#
#               CATEGORY           BRAND OWNER                         BRAND  \
# 0     ABRASIVE CL PADS                    3M                  SCOTCH BRITE
# 1     ABRASIVE CL PADS             ALL OTHER                     ALL OTHER
# 2     ABRASIVE CL PADS     COLGATE PALMOLIVE      AJAX (COLGATE PALMOLIVE)
# 3     ABRASIVE CL PADS           FREUDENBERG                        VILEDA
# 4     ABRASIVE CL PADS         NEWELL BRANDS                       SPONTEX
# ...                ...                   ...                           ...
# 5260    SKIN CLEANSING               SODALIS             VITESSE (SODALIS)
# 5261    SKIN CLEANSING              UNILEVER    DOVE (UNILEVER / UNILEVER)
# 5262    SKIN CLEANSING              UNILEVER     REN (UNILEVER / UNILEVER)
# 5263    SKIN CLEANSING                WELEDA                        WELEDA
# 5264    SKIN CLEANSING  YELLOW WOOD PARTNERS  PONDS (YELLOW WOOD PARTNERS)
#
#       Penetration Latest 52 Wks  Value vs YA (Abs Change) Latest 52 Wks  \
# 0                         2.819                           -2.816270e+05
# 1                        29.041                            1.402825e+07
# 2                           NaN                           -4.565028e+03
# 3                         0.488                            2.342170e+05
# 4                        37.546                            1.144235e+06
# ...                         ...                                     ...
# 5260                      1.049                           -2.577675e+05
# 5261                        NaN                           -2.836982e+04
# 5262                      0.005                            1.886498e+04
# 5263                      0.034                            1.966220e+04
# 5264                      0.011                           -2.534527e+03
#
#       Value due to Buyers YA Latest 52 Wks  \
# 0                              -125211.791
# 1                              5187110.253
# 2                                      NaN
# 3                               310890.571
# 4                              -231956.527
# ...                                    ...
# 5260                           -654667.168
# 5261                                   NaN
# 5262                                   NaN
# 5263                             19322.068
# 5264                             -3278.416
#
#       Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                             -6940.783
# 1                                           4381444.346
# 2                                                   NaN
# 3                                             -2794.563
# 4                                           -777751.959
# ...                                                 ...
# 5260                                         373307.212
# 5261                                                NaN
# 5262                                                NaN
# 5263                                            161.330
# 5264                                              0.000
#
#       Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                          -149477.240
# 1                                          4459689.949
# 2                                                  NaN
# 3                                           -73880.617
# 4                                          2153942.130
# ...                                                ...
# 5260                                         23593.632
# 5261                                               NaN
# 5262                                               NaN
# 5263                                           181.241
# 5264                                           745.103
#
#       Penetration Latest 26 Wks  Value vs YA (Abs Change) Latest 26 Wks  \
# 0                         1.347                             -467747.807
# 1                        19.432                             5185968.980
# 2                           NaN                               -4565.028
# 3                         0.300                               75419.427
# 4                        26.582                              362865.133
# ...                         ...                                     ...
# 5260                      0.864                              -63081.555
# 5261                        NaN                                     NaN
# 5262                        NaN                                     NaN
# 5263                      0.002                                4269.966
# 5264                      0.002                               -4066.432
#
#       Value due to Buyers YA Latest 26 Wks  \
# 0                              -387638.647
# 1                              1594138.737
# 2                                      NaN
# 3                                91236.705
# 4                              -515417.269
# ...                                    ...
# 5260                             92476.682
# 5261                                   NaN
# 5262                                   NaN
# 5263                                   NaN
# 5264                             -4573.227
#
#       Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                             92471.589
# 1                                           1249741.075
# 2                                                   NaN
# 3                                              -150.418
# 4                                           -508856.667
# ...                                                 ...
# 5260                                        -167001.323
# 5261                                                NaN
# 5262                                                NaN
# 5263                                                NaN
# 5264                                             44.810
#
#       Value due to Value per Occasion YA Latest 26 Wks
# 0                                          -172577.218
# 1                                          2342089.327
# 2                                                  NaN
# 3                                           -15666.805
# 4                                          1387139.758
# ...                                                ...
# 5260                                         11444.334
# 5261                                               NaN
# 5262                                               NaN
# 5263                                               NaN
# 5264                                           466.165
#
# [5265 rows x 18 columns]

# %%
df2_processed=df2_processed.fillna(0)
df2_processed
# Out:
#             People Currency  Total Panel  Total Outlets Countries  \
# 0     People Group      EUR  Total Panel  Total Outlets    France
# 1     People Group      EUR  Total Panel  Total Outlets    France
# 2     People Group      EUR  Total Panel  Total Outlets    France
# 3     People Group      EUR  Total Panel  Total Outlets    France
# 4     People Group      EUR  Total Panel  Total Outlets    France
# ...            ...      ...          ...            ...       ...
# 5260  People Group      EUR  Total Panel  Total Outlets     Spain
# 5261  People Group      EUR  Total Panel  Total Outlets     Spain
# 5262  People Group      EUR  Total Panel  Total Outlets     Spain
# 5263  People Group      EUR  Total Panel  Total Outlets     Spain
# 5264  People Group      EUR  Total Panel  Total Outlets     Spain
#
#               CATEGORY           BRAND OWNER                         BRAND  \
# 0     ABRASIVE CL PADS                    3M                  SCOTCH BRITE
# 1     ABRASIVE CL PADS             ALL OTHER                     ALL OTHER
# 2     ABRASIVE CL PADS     COLGATE PALMOLIVE      AJAX (COLGATE PALMOLIVE)
# 3     ABRASIVE CL PADS           FREUDENBERG                        VILEDA
# 4     ABRASIVE CL PADS         NEWELL BRANDS                       SPONTEX
# ...                ...                   ...                           ...
# 5260    SKIN CLEANSING               SODALIS             VITESSE (SODALIS)
# 5261    SKIN CLEANSING              UNILEVER    DOVE (UNILEVER / UNILEVER)
# 5262    SKIN CLEANSING              UNILEVER     REN (UNILEVER / UNILEVER)
# 5263    SKIN CLEANSING                WELEDA                        WELEDA
# 5264    SKIN CLEANSING  YELLOW WOOD PARTNERS  PONDS (YELLOW WOOD PARTNERS)
#
#       Penetration Latest 52 Wks  Value vs YA (Abs Change) Latest 52 Wks  \
# 0                         2.819                           -2.816270e+05
# 1                        29.041                            1.402825e+07
# 2                         0.000                           -4.565028e+03
# 3                         0.488                            2.342170e+05
# 4                        37.546                            1.144235e+06
# ...                         ...                                     ...
# 5260                      1.049                           -2.577675e+05
# 5261                      0.000                           -2.836982e+04
# 5262                      0.005                            1.886498e+04
# 5263                      0.034                            1.966220e+04
# 5264                      0.011                           -2.534527e+03
#
#       Value due to Buyers YA Latest 52 Wks  \
# 0                              -125211.791
# 1                              5187110.253
# 2                                    0.000
# 3                               310890.571
# 4                              -231956.527
# ...                                    ...
# 5260                           -654667.168
# 5261                                 0.000
# 5262                                 0.000
# 5263                             19322.068
# 5264                             -3278.416
#
#       Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                             -6940.783
# 1                                           4381444.346
# 2                                                 0.000
# 3                                             -2794.563
# 4                                           -777751.959
# ...                                                 ...
# 5260                                         373307.212
# 5261                                              0.000
# 5262                                              0.000
# 5263                                            161.330
# 5264                                              0.000
#
#       Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                          -149477.240
# 1                                          4459689.949
# 2                                                0.000
# 3                                           -73880.617
# 4                                          2153942.130
# ...                                                ...
# 5260                                         23593.632
# 5261                                             0.000
# 5262                                             0.000
# 5263                                           181.241
# 5264                                           745.103
#
#       Penetration Latest 26 Wks  Value vs YA (Abs Change) Latest 26 Wks  \
# 0                         1.347                             -467747.807
# 1                        19.432                             5185968.980
# 2                         0.000                               -4565.028
# 3                         0.300                               75419.427
# 4                        26.582                              362865.133
# ...                         ...                                     ...
# 5260                      0.864                              -63081.555
# 5261                      0.000                                   0.000
# 5262                      0.000                                   0.000
# 5263                      0.002                                4269.966
# 5264                      0.002                               -4066.432
#
#       Value due to Buyers YA Latest 26 Wks  \
# 0                              -387638.647
# 1                              1594138.737
# 2                                    0.000
# 3                                91236.705
# 4                              -515417.269
# ...                                    ...
# 5260                             92476.682
# 5261                                 0.000
# 5262                                 0.000
# 5263                                 0.000
# 5264                             -4573.227
#
#       Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                             92471.589
# 1                                           1249741.075
# 2                                                 0.000
# 3                                              -150.418
# 4                                           -508856.667
# ...                                                 ...
# 5260                                        -167001.323
# 5261                                              0.000
# 5262                                              0.000
# 5263                                              0.000
# 5264                                             44.810
#
#       Value due to Value per Occasion YA Latest 26 Wks
# 0                                          -172577.218
# 1                                          2342089.327
# 2                                                0.000
# 3                                           -15666.805
# 4                                          1387139.758
# ...                                                ...
# 5260                                         11444.334
# 5261                                             0.000
# 5262                                             0.000
# 5263                                             0.000
# 5264                                           466.165
#
# [5265 rows x 18 columns]

# %%
df2_processed.columns
# Out:
# Index(['People', 'Currency', 'Total Panel', 'Total Outlets', 'Countries',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'Penetration Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Penetration Latest 26 Wks', 'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')

# %%
Top_Oppurtunity
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 8          1  People Group      EUR  Total Panel  Total Outlets
# 15         3  People Group      EUR  Total Panel  Total Outlets
# 21         5  People Group      EUR  Total Panel  Total Outlets
# 30         7  People Group      EUR  Total Panel  Total Outlets
# 61        18  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 7815    2887  People Group      EUR  Total Panel  Total Outlets
# 7866    2903  People Group      EUR  Total Panel  Total Outlets
# 8055    2974  People Group      EUR  Total Panel  Total Outlets
# 8106    2988  People Group      EUR  Total Panel  Total Outlets
# 8133    2998  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY        BRAND OWNER                      BRAND  country  \
# 8     ABRASIVE CL PADS          ALL OTHER                  ALL OTHER  Germany
# 15    ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)    Italy
# 21    ABRASIVE CL PADS        FREUDENBERG                     VILEDA  Germany
# 30    ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX    Italy
# 61        ADULT INCONT             ESSITY              TENA (ESSITY)       GB
# ...                ...                ...                        ...      ...
# 7815    SKIN CLEANSING          ALL OTHER                  ALL OTHER       GB
# 7866    SKIN CLEANSING       BOLTON GROUP            ACQUA ALLE ROSE    Italy
# 8055    SKIN CLEANSING     KIMBERLY CLARK                    HUGGIES    Italy
# 8106    SKIN CLEANSING            L'OREAL   MIXA (L'OREAL / L'OREAL)   France
# 8133    SKIN CLEANSING         LEA NATURE                SO'BIO ETIC   France
#
#       Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 8             5.621            1.342          8.716            0.877
# 15            2.184            0.290          3.350            0.180
# 21            4.371            0.630          6.745            0.319
# 30           11.639            1.371         17.913            0.985
# 61           10.823            1.357         12.955            0.586
# ...             ...              ...            ...              ...
# 7815         17.044            0.747         25.194            0.107
# 7866          1.817            0.391          3.015            0.164
# 8055          1.356            0.337          2.063            0.259
# 8106          5.101            0.223          7.754            0.194
# 8133          1.536            0.252          2.637            0.177
#
#      Tangible Brands Growing Penetration Accelerating Penetration  \
# 8                Yes                 Yes                      Yes
# 15               Yes                 Yes                      Yes
# 21               Yes                 Yes                      Yes
# 30               Yes                 Yes                      Yes
# 61               Yes                 Yes                      Yes
# ...              ...                 ...                      ...
# 7815             Yes                 Yes                      Yes
# 7866             Yes                 Yes                      Yes
# 8055             Yes                 Yes                      Yes
# 8106             Yes                 Yes                      Yes
# 8133             Yes                 Yes                      Yes
#
#      Top Opportunity
# 8                Yes
# 15               Yes
# 21               Yes
# 30               Yes
# 61               Yes
# ...              ...
# 7815             Yes
# 7866             Yes
# 8055             Yes
# 8106             Yes
# 8133             Yes
#
# [210 rows x 17 columns]

# %%
# merge procedure between Top_Oppurtunity (from df_final) and df2_processed
# assume df_final and df2_processed exist

# select necessary columns from df2_processed
right_cols = [
    'Countries','CATEGORY','BRAND',
    'Value vs YA (Abs Change) Latest 52 Wks',
    'Value due to Buyers YA Latest 52 Wks',
    'Value due to Occasions per Buyer YA Latest 52 Wks',
    'Value due to Value per Occasion YA Latest 52 Wks',
    'Value vs YA (Abs Change) Latest 26 Wks',
    'Value due to Buyers YA Latest 26 Wks',
    'Value due to Occasions per Buyer YA Latest 26 Wks',
    'Value due to Value per Occasion YA Latest 26 Wks',
]

# build small right table
df2_small = df2_processed[right_cols].copy()

# perform left merge
Top_Oppurtunity = df_final[df_final['Top Opportunity']=='Yes']

df_merged = Top_Oppurtunity.merge(
    df2_small,
    left_on=['country','CATEGORY','BRAND'],
    right_on=['Countries','CATEGORY','BRAND'],
    how='left'
)

# drop auxiliary column
if 'Countries' in df_merged.columns:
    df_merged = df_merged.drop(columns=['Countries'])

# show result
print(df_merged.columns)
df_merged.head()
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')
#    row_id        People Currency  Total Panel  Total Outlets  \
# 0       1  People Group      EUR  Total Panel  Total Outlets
# 1       3  People Group      EUR  Total Panel  Total Outlets
# 2       5  People Group      EUR  Total Panel  Total Outlets
# 3       7  People Group      EUR  Total Panel  Total Outlets
# 4      18  People Group      EUR  Total Panel  Total Outlets
#
#            CATEGORY        BRAND OWNER                      BRAND  country  \
# 0  ABRASIVE CL PADS          ALL OTHER                  ALL OTHER  Germany
# 1  ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)    Italy
# 2  ABRASIVE CL PADS        FREUDENBERG                     VILEDA  Germany
# 3  ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX    Italy
# 4      ADULT INCONT             ESSITY              TENA (ESSITY)       GB
#
#    Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 0          5.621            1.342          8.716            0.877
# 1          2.184            0.290          3.350            0.180
# 2          4.371            0.630          6.745            0.319
# 3         11.639            1.371         17.913            0.985
# 4         10.823            1.357         12.955            0.586
#
#   Tangible Brands Growing Penetration Accelerating Penetration  \
# 0             Yes                 Yes                      Yes
# 1             Yes                 Yes                      Yes
# 2             Yes                 Yes                      Yes
# 3             Yes                 Yes                      Yes
# 4             Yes                 Yes                      Yes
#
#   Top Opportunity  Value vs YA (Abs Change) Latest 52 Wks  \
# 0             Yes                              791926.913
# 1             Yes                              -42369.452
# 2             Yes                              853160.781
# 3             Yes                             1242617.725
# 4             Yes                            -5688230.065
#
#    Value due to Buyers YA Latest 52 Wks  \
# 0                           1110128.760
# 1                            108660.475
# 2                            444338.965
# 3                            687083.008
# 4                           8701839.722
#
#    Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                       2.604244e+05
# 1                                      -6.857022e+04
# 2                                      -4.208332e+05
# 3                                       4.138990e+05
# 4                                      -1.457986e+07
#
#    Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                       -578625.594
# 1                                        -82461.060
# 2                                        829654.867
# 3                                        141636.099
# 4                                        189783.265
#
#    Value vs YA (Abs Change) Latest 26 Wks  \
# 0                              446782.207
# 1                               78686.554
# 2                              609011.228
# 3                              978145.473
# 4                            -4966937.546
#
#    Value due to Buyers YA Latest 26 Wks  \
# 0                          1.470200e+06
# 1                          1.437160e+05
# 2                          7.507220e+05
# 3                          7.783581e+05
# 4                          1.294244e+07
#
#    Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                       1.684292e+05
# 1                                      -1.811871e+04
# 2                                      -4.108906e+05
# 3                                      -4.755753e+04
# 4                                      -1.405289e+07
#
#    Value due to Value per Occasion YA Latest 26 Wks
# 0                                      -1191849.092
# 1                                        -46911.006
# 2                                        269179.707
# 3                                        247345.390
# 4                                      -3856464.571

# %%
df_merged.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')

# %%
# calculate contribution percentages for each value component and week
weeks = ['52','26']
components = ['Value due to Buyers YA','Value due to Occasions per Buyer YA','Value due to Value per Occasion YA']

for wk in weeks:
    denom_col = f'Value vs YA (Abs Change) Latest {wk} Wks'
    for comp in components:
        num_col = f'{comp} Latest {wk} Wks'
        new_col = f'Contribution {comp} Latest {wk} Wks'
        df_merged[new_col] = df_merged[num_col] / df_merged[denom_col] * 100

# inspect new columns
df_merged.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#        'Value due to Buyers YA Latest 52 Wks',
#        'Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Value due to Value per Occasion YA Latest 52 Wks',
#        'Value vs YA (Abs Change) Latest 26 Wks',
#        'Value due to Buyers YA Latest 26 Wks',
#        'Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Value due to Value per Occasion YA Latest 26 Wks',
#        'Contribution Value due to Buyers YA Latest 52 Wks',
#        'Contribution Value due to Occasions per Buyer YA Latest 52 Wks',
#        'Contribution Value due to Value per Occasion YA Latest 52 Wks',
#        'Contribution Value due to Buyers YA Latest 26 Wks',
#        'Contribution Value due to Occasions per Buyer YA Latest 26 Wks',
#        'Contribution Value due to Value per Occasion YA Latest 26 Wks'],
#       dtype='object')

# %%
df_merged
# Out:
#      row_id        People Currency  Total Panel  Total Outlets  \
# 0         1  People Group      EUR  Total Panel  Total Outlets
# 1         3  People Group      EUR  Total Panel  Total Outlets
# 2         5  People Group      EUR  Total Panel  Total Outlets
# 3         7  People Group      EUR  Total Panel  Total Outlets
# 4        18  People Group      EUR  Total Panel  Total Outlets
# ..      ...           ...      ...          ...            ...
# 205    2887  People Group      EUR  Total Panel  Total Outlets
# 206    2903  People Group      EUR  Total Panel  Total Outlets
# 207    2974  People Group      EUR  Total Panel  Total Outlets
# 208    2988  People Group      EUR  Total Panel  Total Outlets
# 209    2998  People Group      EUR  Total Panel  Total Outlets
#
#              CATEGORY        BRAND OWNER                      BRAND  country  \
# 0    ABRASIVE CL PADS          ALL OTHER                  ALL OTHER  Germany
# 1    ABRASIVE CL PADS  COLGATE PALMOLIVE  BRAVO (COLGATE PALMOLIVE)    Italy
# 2    ABRASIVE CL PADS        FREUDENBERG                     VILEDA  Germany
# 3    ABRASIVE CL PADS      NEWELL BRANDS                    SPONTEX    Italy
# 4        ADULT INCONT             ESSITY              TENA (ESSITY)       GB
# ..                ...                ...                        ...      ...
# 205    SKIN CLEANSING          ALL OTHER                  ALL OTHER       GB
# 206    SKIN CLEANSING       BOLTON GROUP            ACQUA ALLE ROSE    Italy
# 207    SKIN CLEANSING     KIMBERLY CLARK                    HUGGIES    Italy
# 208    SKIN CLEANSING            L'OREAL   MIXA (L'OREAL / L'OREAL)   France
# 209    SKIN CLEANSING         LEA NATURE                SO'BIO ETIC   France
#
#      Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA  \
# 0            5.621            1.342          8.716            0.877
# 1            2.184            0.290          3.350            0.180
# 2            4.371            0.630          6.745            0.319
# 3           11.639            1.371         17.913            0.985
# 4           10.823            1.357         12.955            0.586
# ..             ...              ...            ...              ...
# 205         17.044            0.747         25.194            0.107
# 206          1.817            0.391          3.015            0.164
# 207          1.356            0.337          2.063            0.259
# 208          5.101            0.223          7.754            0.194
# 209          1.536            0.252          2.637            0.177
#
#     Tangible Brands Growing Penetration Accelerating Penetration  \
# 0               Yes                 Yes                      Yes
# 1               Yes                 Yes                      Yes
# 2               Yes                 Yes                      Yes
# 3               Yes                 Yes                      Yes
# 4               Yes                 Yes                      Yes
# ..              ...                 ...                      ...
# 205             Yes                 Yes                      Yes
# 206             Yes                 Yes                      Yes
# 207             Yes                 Yes                      Yes
# 208             Yes                 Yes                      Yes
# 209             Yes                 Yes                      Yes
#
#     Top Opportunity  Value vs YA (Abs Change) Latest 52 Wks  \
# 0               Yes                              791926.913
# 1               Yes                              -42369.452
# 2               Yes                              853160.781
# 3               Yes                             1242617.725
# 4               Yes                            -5688230.065
# ..              ...                                     ...
# 205             Yes                             7525573.545
# 206             Yes                              119001.492
# 207             Yes                               -3092.676
# 208             Yes                              408411.901
# 209             Yes                             -770343.269
#
#      Value due to Buyers YA Latest 52 Wks  \
# 0                             1110128.760
# 1                              108660.475
# 2                              444338.965
# 3                              687083.008
# 4                             8701839.722
# ..                                    ...
# 205                            734697.575
# 206                            354523.333
# 207                            462796.947
# 208                            915429.142
# 209                            632695.035
#
#      Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                         2.604244e+05
# 1                                        -6.857022e+04
# 2                                        -4.208332e+05
# 3                                         4.138990e+05
# 4                                        -1.457986e+07
# ..                                                 ...
# 205                                      -4.577374e+06
# 206                                      -4.231482e+04
# 207                                       1.597148e+05
# 208                                       9.547586e+05
# 209                                      -5.920484e+05
#
#      Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                       -5.786256e+05
# 1                                       -8.246106e+04
# 2                                        8.296549e+05
# 3                                        1.416361e+05
# 4                                        1.897833e+05
# ..                                                ...
# 205                                      1.136824e+07
# 206                                     -1.932129e+05
# 207                                     -6.256044e+05
# 208                                     -1.461771e+06
# 209                                     -8.109819e+05
#
#      Value vs YA (Abs Change) Latest 26 Wks  \
# 0                                446782.207
# 1                                 78686.554
# 2                                609011.228
# 3                                978145.473
# 4                              -4966937.546
# ..                                      ...
# 205                             7419946.919
# 206                              550176.846
# 207                              119924.810
# 208                              670911.345
# 209                             -135026.411
#
#      Value due to Buyers YA Latest 26 Wks  \
# 0                            1.470200e+06
# 1                            1.437160e+05
# 2                            7.507220e+05
# 3                            7.783581e+05
# 4                            1.294244e+07
# ..                                    ...
# 205                          1.606775e+06
# 206                          7.255667e+05
# 207                          4.884227e+05
# 208                          6.583396e+05
# 209                          6.859965e+05
#
#      Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                         1.684292e+05
# 1                                        -1.811871e+04
# 2                                        -4.108906e+05
# 3                                        -4.755753e+04
# 4                                        -1.405289e+07
# ..                                                 ...
# 205                                      -1.160366e+06
# 206                                       7.277008e+04
# 207                                      -2.773019e+05
# 208                                       3.832285e+05
# 209                                      -3.715906e+05
#
#      Value due to Value per Occasion YA Latest 26 Wks  \
# 0                                        -1191849.092
# 1                                          -46911.006
# 2                                          269179.707
# 3                                          247345.390
# 4                                        -3856464.571
# ..                                                ...
# 205                                       6973537.944
# 206                                       -248162.122
# 207                                        -91199.930
# 208                                       -370656.080
# 209                                       -449430.496
#
#      Contribution Value due to Buyers YA Latest 52 Wks  \
# 0                                           140.180709
# 1                                          -256.459477
# 2                                            52.081504
# 3                                            55.293192
# 4                                          -152.979743
# ..                                                 ...
# 205                                           9.762679
# 206                                         297.915032
# 207                                      -14964.288112
# 208                                         224.143601
# 209                                         -82.131572
#
#      Contribution Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                            32.884903
# 1                                           161.838820
# 2                                           -49.326359
# 3                                            33.308635
# 4                                           256.316368
# ..                                                 ...
# 205                                         -60.824249
# 206                                         -35.558230
# 207                                       -5164.292768
# 208                                         233.773440
# 209                                          76.855144
#
#      Contribution Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                           -73.065530
# 1                                           194.623853
# 2                                            97.244844
# 3                                            11.398204
# 4                                            -3.336420
# ..                                                 ...
# 205                                         151.061502
# 206                                        -162.361717
# 207                                       20228.579521
# 208                                        -357.915885
# 209                                         105.275388
#
#      Contribution Value due to Buyers YA Latest 26 Wks  \
# 0                                           329.064162
# 1                                           182.643656
# 2                                           123.268986
# 3                                            79.574886
# 4                                          -260.571783
# ..                                                 ...
# 205                                          21.654806
# 206                                         131.878814
# 207                                         407.274097
# 208                                          98.126172
# 209                                        -508.046181
#
#      Contribution Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                            37.698273
# 1                                           -23.026435
# 2                                           -67.468472
# 3                                            -4.862010
# 4                                           282.928720
# ..                                                 ...
# 205                                         -15.638465
# 206                                          13.226671
# 207                                        -231.229829
# 208                                          57.120583
# 209                                         275.198463
#
#      Contribution Value due to Value per Occasion YA Latest 26 Wks
# 0                                          -266.762882
# 1                                           -59.617563
# 2                                            44.199465
# 3                                            25.287178
# 4                                            77.642703
# ..                                                 ...
# 205                                          93.983663
# 206                                         -45.105883
# 207                                         -76.047592
# 208                                         -55.246656
# 209                                         332.846361
#
# [210 rows x 31 columns]

# %%
# Sort df_merged by Value vs YA (Abs Change) Latest 13 Wks in descending order
df_priority = df_merged.sort_values(
    by='Value vs YA (Abs Change) Latest 26 Wks',
    ascending=False
).reset_index(drop=True)

df_priority
# Out:
#      row_id        People Currency  Total Panel  Total Outlets  \
# 0        52  People Group      EUR  Total Panel  Total Outlets
# 1      2832  People Group      EUR  Total Panel  Total Outlets
# 2       920  People Group      EUR  Total Panel  Total Outlets
# 3      2699  People Group      EUR  Total Panel  Total Outlets
# 4      1940  People Group      EUR  Total Panel  Total Outlets
# ..      ...           ...      ...          ...            ...
# 205    2759  People Group      EUR  Total Panel  Total Outlets
# 206    2778  People Group      EUR  Total Panel  Total Outlets
# 207    2784  People Group      EUR  Total Panel  Total Outlets
# 208    2809  People Group      EUR  Total Panel  Total Outlets
# 209    2832  People Group      EUR  Total Panel  Total Outlets
#
#                 CATEGORY        BRAND OWNER  \
# 0          ADW DETERGENT   PROCTER & GAMBLE
# 1    VITAMIN SUPPLEMENTS          ALL OTHER
# 2            FABRIC SOFT      PRIVATE LABEL
# 3           TOILET PAPER             ESSITY
# 4            LAUNDRY DET   PROCTER & GAMBLE
# ..                   ...                ...
# 205           TOOTHPASTE  COLGATE PALMOLIVE
# 206           TOOTHPASTE             HALEON
# 207           TOOTHPASTE             HALEON
# 208           TOOTHPASTE      PRIVATE LABEL
# 209  VITAMIN SUPPLEMENTS          ALL OTHER
#
#                                            BRAND       country  Latest 26 Wks  \
# 0    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)        France          9.842
# 1                                      ALL OTHER       Germany         14.466
# 2                                  PRIVATE LABEL         Spain         55.363
# 3                                           ZEWA       Germany         11.586
# 4    ARIEL (PROCTER & GAMBLE / PROCTER & GAMBLE)            GB         13.808
# ..                                           ...           ...            ...
# 205                  COLGATE (COLGATE PALMOLIVE)  Total Europe         30.231
# 206                           AQUAFRESH (HALEON)  Total Europe          6.062
# 207                          ODOL MED 3 (HALEON)  Total Europe          4.104
# 208                                PRIVATE LABEL  Total Europe         17.133
# 209                                    ALL OTHER  Total Europe          8.752
#
#      Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA Tangible Brands  \
# 0              2.698         13.809            1.781             Yes
# 1              2.155         19.098            1.344             Yes
# 2              0.493         63.894            0.339             Yes
# 3              1.591         16.281            1.298             Yes
# 4              0.408         18.207           -0.199             Yes
# ..               ...            ...              ...             ...
# 205            0.733         39.029            0.404             Yes
# 206            0.391          9.059            0.084             Yes
# 207            0.824          6.043            0.790             Yes
# 208            0.689         24.078            0.298             Yes
# 209            0.576         12.716            0.573             Yes
#
#     Growing Penetration Accelerating Penetration Top Opportunity  \
# 0                   Yes                      Yes             Yes
# 1                   Yes                      Yes             Yes
# 2                   Yes                      Yes             Yes
# 3                   Yes                      Yes             Yes
# 4                   Yes                      Yes             Yes
# ..                  ...                      ...             ...
# 205                 Yes                      Yes             Yes
# 206                 Yes                      Yes             Yes
# 207                 Yes                      Yes             Yes
# 208                 Yes                      Yes             Yes
# 209                 Yes                      Yes             Yes
#
#      Value vs YA (Abs Change) Latest 52 Wks  \
# 0                              2.405763e+07
# 1                              8.623709e+06
# 2                              1.675381e+07
# 3                              6.528892e+06
# 4                              1.335732e+07
# ..                                      ...
# 205                                     NaN
# 206                                     NaN
# 207                                     NaN
# 208                                     NaN
# 209                                     NaN
#
#      Value due to Buyers YA Latest 52 Wks  \
# 0                            1.377025e+07
# 1                            1.080711e+07
# 2                            2.521797e+06
# 3                            9.307322e+06
# 4                           -5.466577e+05
# ..                                    ...
# 205                                   NaN
# 206                                   NaN
# 207                                   NaN
# 208                                   NaN
# 209                                   NaN
#
#      Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                         1.780857e+06
# 1                                         3.044560e+06
# 2                                         1.522746e+07
# 3                                        -8.080408e+06
# 4                                         4.213361e+06
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                         8506531.224
# 1                                        -5227967.820
# 2                                         -995450.501
# 3                                         5301963.615
# 4                                         9690620.806
# ..                                                ...
# 205                                               NaN
# 206                                               NaN
# 207                                               NaN
# 208                                               NaN
# 209                                               NaN
#
#      Value vs YA (Abs Change) Latest 26 Wks  \
# 0                              2.801299e+07
# 1                              1.123335e+07
# 2                              1.028623e+07
# 3                              9.308653e+06
# 4                              8.807401e+06
# ..                                      ...
# 205                                     NaN
# 206                                     NaN
# 207                                     NaN
# 208                                     NaN
# 209                                     NaN
#
#      Value due to Buyers YA Latest 26 Wks  \
# 0                            1.615693e+07
# 1                            1.237497e+07
# 2                            1.631086e+06
# 3                            8.524028e+06
# 4                            3.735037e+06
# ..                                    ...
# 205                                   NaN
# 206                                   NaN
# 207                                   NaN
# 208                                   NaN
# 209                                   NaN
#
#      Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                         7.763204e+04
# 1                                        -9.578544e+05
# 2                                         1.135142e+07
# 3                                        -2.425330e+06
# 4                                        -1.096379e+06
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Value due to Value per Occasion YA Latest 26 Wks  \
# 0                                        1.177843e+07
# 1                                       -1.837710e+05
# 2                                       -2.696273e+06
# 3                                        3.209952e+06
# 4                                        6.168742e+06
# ..                                                ...
# 205                                               NaN
# 206                                               NaN
# 207                                               NaN
# 208                                               NaN
# 209                                               NaN
#
#      Contribution Value due to Buyers YA Latest 52 Wks  \
# 0                                            57.238578
# 1                                           125.318534
# 2                                            15.052075
# 3                                           142.555909
# 4                                            -4.092570
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Contribution Value due to Occasions per Buyer YA Latest 52 Wks  \
# 0                                             7.402460
# 1                                            35.304530
# 2                                            90.889486
# 3                                          -123.763842
# 4                                            31.543455
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Contribution Value due to Value per Occasion YA Latest 52 Wks  \
# 0                                            35.358970
# 1                                           -60.623195
# 2                                            -5.941635
# 3                                            81.207707
# 4                                            72.549129
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Contribution Value due to Buyers YA Latest 26 Wks  \
# 0                                            57.676559
# 1                                           110.162817
# 2                                            15.856980
# 3                                            91.571016
# 4                                            42.407941
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Contribution Value due to Occasions per Buyer YA Latest 26 Wks  \
# 0                                             0.277129
# 1                                            -8.526882
# 2                                           110.355447
# 3                                           -26.054576
# 4                                           -12.448386
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
#      Contribution Value due to Value per Occasion YA Latest 26 Wks
# 0                                            42.046306
# 1                                            -1.635942
# 2                                           -26.212446
# 3                                            34.483524
# 4                                            70.040437
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
#
# [210 rows x 31 columns]

# %%
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347           -0.365          2.819
# 1               GB          0.328           -0.083          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.011          0.256
# 8336        France          0.005            0.005          0.005
# 8337            GB          0.302            0.302          0.450
# 8338  Total Europe          0.059            0.059          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration  \
# 0              -0.136             Yes                  No
# 1              -0.170              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335           -0.014              No                  No
# 8336            0.005              No                  No
# 8337            0.450              No                 Yes
# 8338            0.087              No                  No
#
#      Accelerating Penetration Top Opportunity
# 0                          No              No
# 1                         Yes              No
# 2                         Yes              No
# 3                         Yes              No
# 4                          No              No
# ...                       ...             ...
# 8334                       No              No
# 8335                      Yes              No
# 8336                       No              No
# 8337                       No              No
# 8338                       No              No
#
# [8339 rows x 17 columns]

# %% [markdown]
# # pg risk

# %%
# define a helper that applies the two rules only for P&G brands
# brand_owner is now a parameter with a default value; the result
# column name is constructed separately so we can reference it easily.
def calculate_pg_risk(row, brand_owner='PROCTER & GAMBLE'):
    if row['BRAND OWNER'] != brand_owner:
        return 'No'                       # keep others as “No”
    l52 = row['Latest 52 vs YA']
    l26 = row['Latest 26 vs YA']

    # declining‑growth
    if l52 > 0 and l26 < l52 :
        return 'Growth Deceleration'
    # declining‑deceleration
    if l52 < 0 and l26 < l52:
        return 'Decline Acceleration'
    return 'No'

# assign the column
brand_owner = 'PROCTER & GAMBLE'
colname = f"{brand_owner} risk"
# use a lambda to pass the brand_owner argument to the function
# (alternatively the default value in calculate_pg_risk could be used)
df_final[colname] = df_final.apply(lambda r: calculate_pg_risk(r, brand_owner), axis=1)

# quick check
print(df_final[colname].value_counts())
print(df_final[df_final['BRAND OWNER']==brand_owner][['BRAND','country',
      'Latest 52 vs YA','Latest 26 vs YA',colname]].head())
# Out:
# PROCTER & GAMBLE risk
# No                      8063
# Growth Deceleration      171
# Decline Acceleration     105
# Name: count, dtype: int64
#                                             BRAND       country  \
# 39                                     DON LIMPIO         Spain
# 40                                     DON LIMPIO  Total Europe
# 41    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)            GB
# 42    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)  Total Europe
# 116  ALWAYS (PROCTER & GAMBLE / PROCTER & GAMBLE)        France
#
#      Latest 52 vs YA  Latest 26 vs YA PROCTER & GAMBLE risk
# 39            -0.096           -0.078                    No
# 40            -0.012           -0.009                    No
# 41            -0.299           -0.045                    No
# 42            -0.057           -0.009                    No
# 116           -0.303            0.405                    No

# %%
# RECHECK: Full verification of P&G risk logic starting with P&G data
print("="*80)
print("FULL RECHECK: LOGIC VERIFICATION")
print("="*80)

# Step 1: Filter for PROCTER & GAMBLE brands
pg_brands = df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE'].copy()
print(f"\n✓ Total P&G rows in df_final: {len(pg_brands)}")
print(f"✓ Total rows in df_final: {len(df_final)}")

# Step 2: Check P&G risk column exists
if 'P&G risk' in df_final.columns:
    print(f"✓ P&G risk column exists in df_final")
else:
    print("✗ ERROR: P&G risk column NOT found in df_final")

# Step 3: Verify logic for each risk category
print("\n" + "="*80)
print("RISK CATEGORY VERIFICATION")
print("="*80)

# Declining growth: Latest 52 > 0 AND (Latest 26 < Latest 52 OR Latest 13 < Latest 52)
declining_growth = pg_brands[
    (pg_brands['Latest 52 vs YA'] > 0) & 
    (pg_brands['Latest 26 vs YA'] < pg_brands['Latest 52 vs YA']) 
]

declining_growth_marked = pg_brands[pg_brands['P&G risk'] == 'Growth Deceleration']

print(f"\n1. DECLINING GROWTH:")
print(f"   Expected logic count: {len(declining_growth)}")
print(f"   Marked as 'Declining growth': {len(declining_growth_marked)}")
print(f"   Match: {'✓ YES' if len(declining_growth) == len(declining_growth_marked) else '✗ NO'}")

# Declining Deceleration: Latest 52 < 0 AND (Latest 26 > Latest 52 OR Latest 13 > Latest 52)
declining_deceleration = pg_brands[
    (pg_brands['Latest 52 vs YA'] < 0) & 
    (pg_brands['Latest 26 vs YA'] < pg_brands['Latest 52 vs YA']) 
]

declining_deceleration_marked = pg_brands[pg_brands['P&G risk'] == 'Decline Acceleration']

print(f"\n2. DECLINING DECELERATION:")
print(f"   Expected logic count: {len(declining_deceleration)}")
print(f"   Marked as 'Declining Deceleration': {len(declining_deceleration_marked)}")
print(f"   Match: {'✓ YES' if len(declining_deceleration) == len(declining_deceleration_marked) else '✗ NO'}")

# No risk: Everything else (including non-P&G)
no_risk_pg = pg_brands[pg_brands['P&G risk'] == 'No']
print(f"\n3. NO RISK (P&G brands only):")
print(f"   Count: {len(no_risk_pg)}")

# Step 4: Overall distribution
print("\n" + "="*80)
print("OVERALL P&G RISK DISTRIBUTION")
print("="*80)
print(df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE']['P&G risk'].value_counts())

print("\n" + "="*80)
print("NON-P&G BRANDS - SHOULD ALL BE 'No'")
print("="*80)
non_pg = df_final[df_final['BRAND OWNER']!='PROCTER & GAMBLE']
non_pg_risk_dist = non_pg['P&G risk'].value_counts()
print(non_pg_risk_dist)
if len(non_pg_risk_dist) == 1 and non_pg_risk_dist.index[0] == 'No':
    print("✓ All non-P&G brands correctly marked as 'No'")
else:
    print("✗ ERROR: Some non-P&G brands have risk values other than 'No'")

# Step 5: Sample verification rows
print("\n" + "="*80)
print("SAMPLE ROWS - DETAILED VERIFICATION")
print("="*80)

print("\nSample DECLINING GROWTH rows:")
declining_growth_sample = declining_growth_marked[['BRAND', 'country', 'Latest 52 vs YA', 'Latest 26 vs YA',  'P&G risk']].head(5)
print(declining_growth_sample)
print("Logic check (for each row, Latest 52 > 0 and min(26,13) < 52):")
for idx, row in declining_growth_sample.iterrows():
    l52 = row['Latest 52 vs YA']
    l26 = row['Latest 26 vs YA']

    print(f"  {row['BRAND']}: 52={l52:.3f} (>0?{l52>0}), 26={l26:.3f}(<52?{l26<l52})")

print("\nSample DECLINING DECELERATION rows:")
declining_deceleration_sample = declining_deceleration_marked[['BRAND', 'country', 'Latest 52 vs YA', 'Latest 26 vs YA', 'P&G risk']].head(5)
print(declining_deceleration_sample)
print("Logic check (for each row, Latest 52 < 0 and max(26,13) > 52):")
for idx, row in declining_deceleration_sample.iterrows():
    l52 = row['Latest 52 vs YA']
    l26 = row['Latest 26 vs YA']
    print(f"  {row['BRAND']}: 52={l52:.3f} (<0?{l52<0}), 26={l26:.3f}(>52?{l26>l52})")

print("\n" + "="*80)
print("VERIFICATION COMPLETE")
print("="*80)
# Out:
# ================================================================================
# FULL RECHECK: LOGIC VERIFICATION
# ================================================================================
#
# ✓ Total P&G rows in df_final: 653
# ✓ Total rows in df_final: 8339
# ✗ ERROR: P&G risk column NOT found in df_final
#
# ================================================================================
# RISK CATEGORY VERIFICATION
# ================================================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P&G risk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 28
#      22 # Declining growth: Latest 52 > 0 AND (Latest 26 < Latest 52 OR Latest 13 < Latest 52)
#      23 declining_growth = pg_brands[
#      24     (pg_brands['Latest 52 vs YA'] > 0) &
#      25     (pg_brands['Latest 26 vs YA'] < pg_brands['Latest 52 vs YA'])
#      26 ]
# ---> 28 declining_growth_marked = pg_brands[pg_brands['P&G risk'] == 'Growth Deceleration']
#      30 print(f"\n1. DECLINING GROWTH:")
#      31 print(f"   Expected logic count: {len(declining_growth)}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'P&G risk'

# %%
df_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 0          0  People Group      EUR  Total Panel  Total Outlets
# 1          0  People Group      EUR  Total Panel  Total Outlets
# 2          0  People Group      EUR  Total Panel  Total Outlets
# 3          0  People Group      EUR  Total Panel  Total Outlets
# 4          0  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 8334    3072  People Group      EUR  Total Panel  Total Outlets
# 8335    3072  People Group      EUR  Total Panel  Total Outlets
# 8336    3073  People Group      EUR  Total Panel  Total Outlets
# 8337    3073  People Group      EUR  Total Panel  Total Outlets
# 8338    3073  People Group      EUR  Total Panel  Total Outlets
#
#               CATEGORY           BRAND OWNER                            BRAND  \
# 0     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 1     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 2     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 3     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# 4     ABRASIVE CL PADS                    3M                     SCOTCH BRITE
# ...                ...                   ...                              ...
# 8334    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8335    SKIN CLEANSING  YELLOW WOOD PARTNERS  ST. IVES (YELLOW WOOD PARTNERS)
# 8336    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8337    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
# 8338    SKIN CLEANSING             ZURU EDGE                DAISE (ZURU EDGE)
#
#            country  Latest 26 Wks  Latest 26 vs YA  Latest 52 Wks  \
# 0           France          1.347            0.000          2.819
# 1               GB          0.328            0.000          0.578
# 2          Germany          0.025            0.025          0.025
# 3            Italy          4.423           -0.775          6.966
# 4            Spain          7.331           -0.282         12.530
# ...            ...            ...              ...            ...
# 8334         Italy          0.005           -0.004          0.008
# 8335  Total Europe          0.160            0.000          0.256
# 8336        France          0.005            0.000          0.005
# 8337            GB          0.302            0.000          0.450
# 8338  Total Europe          0.059            0.000          0.087
#
#       Latest 52 vs YA Tangible Brands Growing Penetration  \
# 0               0.000             Yes                  No
# 1               0.000              No                  No
# 2               0.000              No                  No
# 3              -1.439             Yes                  No
# 4               0.306             Yes                  No
# ...               ...             ...                 ...
# 8334            0.000              No                  No
# 8335            0.000              No                  No
# 8336            0.000              No                  No
# 8337            0.000              No                  No
# 8338            0.000              No                  No
#
#      Accelerating Penetration Top Opportunity P&G risk
# 0                          No              No       No
# 1                          No              No       No
# 2                         Yes              No       No
# 3                         Yes              No       No
# 4                          No              No       No
# ...                       ...             ...      ...
# 8334                       No              No       No
# 8335                       No              No       No
# 8336                       No              No       No
# 8337                       No              No       No
# 8338                       No              No       No
#
# [8339 rows x 18 columns]

# %%
df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE']['P&G risk'].value_counts()
# Out:
# P&G risk
# No                      541
# Growth Deceleration      68
# Decline Acceleration     44
# Name: count, dtype: int64

# %%
pg_risk_final=df_final[df_final['P&G risk']!='No']
pg_risk_final
# Out:
#       row_id        People Currency  Total Panel  Total Outlets  \
# 118       35  People Group      EUR  Total Panel  Total Outlets
# 166       52  People Group      EUR  Total Panel  Total Outlets
# 168       52  People Group      EUR  Total Panel  Total Outlets
# 347      117  People Group      EUR  Total Panel  Total Outlets
# 353      119  People Group      EUR  Total Panel  Total Outlets
# ...      ...           ...      ...          ...            ...
# 7786    2873  People Group      EUR  Total Panel  Total Outlets
# 8221    3030  People Group      EUR  Total Panel  Total Outlets
# 8222    3030  People Group      EUR  Total Panel  Total Outlets
# 8231    3033  People Group      EUR  Total Panel  Total Outlets
# 8244    3037  People Group      EUR  Total Panel  Total Outlets
#
#                  CATEGORY       BRAND OWNER  \
# 118          ADULT INCONT  PROCTER & GAMBLE
# 166         ADW DETERGENT  PROCTER & GAMBLE
# 168         ADW DETERGENT  PROCTER & GAMBLE
# 347           AFTER SHAVE  PROCTER & GAMBLE
# 353           AFTER SHAVE  PROCTER & GAMBLE
# ...                   ...               ...
# 7786  VITAMIN SUPPLEMENTS  PROCTER & GAMBLE
# 8221       SKIN CLEANSING  PROCTER & GAMBLE
# 8222       SKIN CLEANSING  PROCTER & GAMBLE
# 8231       SKIN CLEANSING  PROCTER & GAMBLE
# 8244       SKIN CLEANSING  PROCTER & GAMBLE
#
#                                              BRAND  country  Latest 26 Wks  \
# 118   ALWAYS (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany          3.480
# 166    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)  Germany          0.006
# 168    FAIRY (PROCTER & GAMBLE / PROCTER & GAMBLE)    Spain         11.064
# 347         GILLETTE (PROCTER & GAMBLE / GILLETTE)    Italy          0.020
# 353                                GILLETTE SERIES    Spain          0.000
# ...                                            ...      ...            ...
# 7786                                   VIGANTOLVIT  Germany          0.281
# 8221                           GILLETTE SATIN CARE    Italy          0.059
# 8222                           GILLETTE SATIN CARE    Spain          0.071
# 8231                              KING C. GILLETTE    Italy          0.000
# 8244                                       PAMPERS  Germany          1.214
#
#       Latest 26 vs YA  Latest 52 Wks  Latest 52 vs YA Tangible Brands  \
# 118            -0.333          5.970            0.112             Yes
# 166            -0.016          0.050            0.024              No
# 168             0.875         18.017            3.325             Yes
# 347            -0.104          0.092           -0.086              No
# 353            -0.063          0.061           -0.019              No
# ...               ...            ...              ...             ...
# 7786            0.024          0.446            0.094              No
# 8221            0.059          0.329            0.329              No
# 8222            0.056          0.177            0.135              No
# 8231           -0.026          0.024           -0.002              No
# 8244           -0.398          2.165            0.022             Yes
#
#      Growing Penetration Accelerating Penetration Top Opportunity  \
# 118                   No                       No              No
# 166                   No                       No              No
# 168                  Yes                       No              No
# 347                   No                       No              No
# 353                   No                       No              No
# ...                  ...                      ...             ...
# 7786                  No                       No              No
# 8221                  No                       No              No
# 8222                  No                       No              No
# 8231                  No                       No              No
# 8244                  No                       No              No
#
#                   P&G risk
# 118    Growth Deceleration
# 166    Growth Deceleration
# 168    Growth Deceleration
# 347   Decline Acceleration
# 353   Decline Acceleration
# ...                    ...
# 7786   Growth Deceleration
# 8221   Growth Deceleration
# 8222   Growth Deceleration
# 8231  Decline Acceleration
# 8244   Growth Deceleration
#
# [112 rows x 18 columns]

# %%
df_final[df_final['BRAND OWNER']=='PROCTER & GAMBLE'].shape
# Out:
# (653, 18)

# %%
df_final['P&G risk'].value_counts()
# Out:
# P&G risk
# No                      8227
# Growth Deceleration       68
# Decline Acceleration      44
# Name: count, dtype: int64

# %%
pg_risk_final.to_excel('pg_risk3.xlsx')

# %%
pg_risk_final.columns
# Out:
# Index(['row_id', 'People', 'Currency', 'Total Panel', 'Total Outlets',
#        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#        'Top Opportunity', 'P&G risk'],
#       dtype='object')

# %%
pg_risk_final1=pg_risk_final[[ 'Currency',
       'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
       'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
       'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
       'Top Opportunity', 'P&G risk']]
pg_risk_final1.to_excel('pg_risk_output.xlsx',index=False)

# %%
df_priority1=df_priority[[ 'Currency', 
       'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
       'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
       'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
       'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
       'Value due to Buyers YA Latest 52 Wks',
       'Value due to Occasions per Buyer YA Latest 52 Wks',
       'Value due to Value per Occasion YA Latest 52 Wks',
       'Value vs YA (Abs Change) Latest 26 Wks',
       'Value due to Buyers YA Latest 26 Wks',
       'Value due to Occasions per Buyer YA Latest 26 Wks',
       'Value due to Value per Occasion YA Latest 26 Wks',
       'Contribution Value due to Buyers YA Latest 52 Wks',
       'Contribution Value due to Occasions per Buyer YA Latest 52 Wks',
       'Contribution Value due to Value per Occasion YA Latest 52 Wks',
       'Contribution Value due to Buyers YA Latest 26 Wks',
       'Contribution Value due to Occasions per Buyer YA Latest 26 Wks',
       'Contribution Value due to Value per Occasion YA Latest 26 Wks']]

df_priority1.to_excel('priority_brands_output.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df_priority1=df_priority[[ 'Currency',
#       2        'CATEGORY', 'BRAND OWNER', 'BRAND', 'country', 'Latest 26 Wks',
#       3        'Latest 26 vs YA', 'Latest 52 Wks', 'Latest 52 vs YA',
#       4        'Tangible Brands', 'Growing Penetration', 'Accelerating Penetration',
#       5        'Top Opportunity', 'Value vs YA (Abs Change) Latest 52 Wks',
#       6        'Value due to Buyers YA Latest 52 Wks',
#       7        'Value due to Occasions per Buyer YA Latest 52 Wks',
#       8        'Value due to Value per Occasion YA Latest 52 Wks',
#       9        'Value vs YA (Abs Change) Latest 26 Wks',
#      10        'Value due to Buyers YA Latest 26 Wks',
#      11        'Value due to Occasions per Buyer YA Latest 26 Wks',
#      12        'Value due to Value per Occasion YA Latest 26 Wks',
#      13        'Contribution Value due to Buyers YA Latest 52 Wks',
#      14        'Contribution Value due to Occasions per Buyer YA Latest 52 Wks',
#      15        'Contribution Value due to Value per Occasion YA Latest 52 Wks',
#      16        'Contribution Value due to Buyers YA Latest 26 Wks',
#      17        'Contribution Value due to Occasions per Buyer YA Latest 26 Wks',
#      18        'Contribution Value due to Value per Occasion YA Latest 26 Wks']]
#      20 df_priority1.to_excel('priority_brands_output.xlsx', index=False)
#
# NameError: name 'df_priority' is not defined
